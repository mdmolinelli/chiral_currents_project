# %%
import matplotlib.pyplot as plt
import numpy as np

import inspect
import beamsplitter_band_assignment as bsa

print("Functions in beamsplitter_band_assignment:")
for name, obj in inspect.getmembers(bsa, inspect.isfunction):
    if obj.__module__ != bsa.__name__:
        continue
    try:
        sig = inspect.signature(obj)
    except (ValueError, TypeError):
        sig = "(...)"
    print(f"{name}{sig}")

    
from beamsplitter_band_assignment import assign_bands
# Out:
# Functions in beamsplitter_band_assignment:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 18
#      14         sig = "(...)"
#      15     print(f"{name}{sig}")
# ---> 18 from beamsplitter_band_assignment import assign_bands
#
# ImportError: cannot import name 'assign_bands' from 'beamsplitter_band_assignment' (c:\Users\mattm\OneDrive\Desktop\Research\Projects\Triangle Lattice\Jupyter Notebooks\8Q_Triangle_Lattice_v1\calibration_algorithms\beamsplitter_band_assignment.py)
