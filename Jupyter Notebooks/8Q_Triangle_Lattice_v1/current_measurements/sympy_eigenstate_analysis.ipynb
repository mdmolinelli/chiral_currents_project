# %%
from sympy import symbols, cos, sin, exp, I, Matrix
from sympy.physics.quantum.tensorproduct import TensorProduct as kron

from sympy import pprint

from itertools import product

init_printing()

# %%
# Define symbolic parameters
theta = symbols('theta_1:5')  # theta_1, ..., theta_4
phi = symbols('phi_1:5')      # phi_1, ..., phi_4

# Define shorthand expressions
c = [cos(t/2) for t in theta]
s = [sin(t/2) for t in theta]
e = [exp(I*p) for p in phi]

# Define individual qubit states
psi = [Matrix([[c[j]], [e[j]*s[j]]]) for j in range(4)]

# Tensor product to get full 4-qubit state
psi_total = psi[0]
for j in range(1, 4):
    psi_total = kron(psi_total, psi[j])

# Full density matrix
rho_full = psi_total * psi_total.H

# Partial trace over qubits 3 and 4 → reduced 4x4 matrix for qubits 1 and 2
rho_12 = Matrix.zeros(4, 4)
for i3, i4 in product([0, 1], repeat=2):
    for i1, i2 in product([0, 1], repeat=2):
        for j1, j2 in product([0, 1], repeat=2):
            row = i1*8 + i2*4 + i3*2 + i4
            col = j1*8 + j2*4 + i3*2 + i4
            rho_12[i1*2 + i2, j1*2 + j2] += rho_full[row, col]

pprint(rho_12)
# Out:
# ⎡                                        __     __                    ⎛__⎞
# ⎢                         ⅈ⋅φ₃  ⅈ⋅φ₄  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₃⎟
# ⎢                        ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin
# ⎢                                                     ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
# ⎢
# ⎢                                  __     __                            ⎛__⎞
# ⎢             ⅈ⋅φ₂  ⅈ⋅φ₃  ⅈ⋅φ₄  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₂⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₃⎟
# ⎢            ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅s
# ⎢                                               ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
# ⎢
# ⎢                                  __     __                            ⎛__⎞
# ⎢             ⅈ⋅φ₁  ⅈ⋅φ₃  ⅈ⋅φ₄  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₃⎟
# ⎢            ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅s
# ⎢                                               ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
# ⎢
# ⎢                            __     __                                    ⎛__⎞
# ⎢ ⅈ⋅φ₁  ⅈ⋅φ₂  ⅈ⋅φ₃  ⅈ⋅φ₄  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₃⎟
# ⎢ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟
# ⎣                                         ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
# ⎛__⎞                    ⎛__⎞    ⎛__⎞             __            ⎛__⎞
# ⎜θ₄⎟    ⎛θ₁⎞    ⎛θ₂⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⅈ⋅φ₃  -ⅈ⋅φ₃    ⎛θ₃⎞    ⎜θ₃⎟    ⎛θ₁⎞
# ⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅co
# ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#   ⎛__⎞            ⎛__⎞    ⎛__⎞                   __                    ⎛__⎞
#   ⎜θ₄⎟    ⎛θ₁⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⅈ⋅φ₂  ⅈ⋅φ₃  -ⅈ⋅φ₃    ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₃⎟
# in⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅co
#   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                         ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#   ⎛__⎞            ⎛__⎞    ⎛__⎞                   __                    ⎛__⎞
#   ⎜θ₄⎟    ⎛θ₂⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⅈ⋅φ₁  ⅈ⋅φ₃  -ⅈ⋅φ₃    ⎛θ₁⎞    ⎛θ₃⎞    ⎜θ₃⎟
# in⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅co
#   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                         ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#     ⎛__⎞    ⎛__⎞    ⎛__⎞                         __
#     ⎜θ₄⎟    ⎜θ₁⎟    ⎜θ₂⎟    ⅈ⋅φ₁  ⅈ⋅φ₂  ⅈ⋅φ₃  -ⅈ⋅φ₃    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞
# ⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅si
#     ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                               ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#                  ⎛__⎞    ⎛__⎞    ⎛__⎞             __            ⎛__⎞
#  ⎛θ₂⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₄⎟    ⅈ⋅φ₄  -ⅈ⋅φ₄    ⎛θ₄⎞    ⎜θ₄⎟    ⎛θ₁⎞
# s⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅c
#  ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#                  ⎛__⎞    ⎛__⎞    ⎛__⎞                   __
#  ⎛θ₁⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₄⎟    ⅈ⋅φ₂  ⅈ⋅φ₄  -ⅈ⋅φ₄    ⎛θ₂⎞    ⎛θ₄⎞
# s⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin
#  ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                         ⎝2 ⎠    ⎝2 ⎠
#
#                  ⎛__⎞    ⎛__⎞    ⎛__⎞                   __
#  ⎛θ₂⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₄⎟    ⅈ⋅φ₁  ⅈ⋅φ₄  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ₄⎞
# s⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin
#  ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                         ⎝2 ⎠    ⎝2 ⎠
#
#  ⎛__⎞            ⎛__⎞    ⎛__⎞    ⎛__⎞                         __
#  ⎜θ₃⎟    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₄⎟    ⅈ⋅φ₁  ⅈ⋅φ₂  ⅈ⋅φ₄  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ
# n⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜─
#  ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                               ⎝2 ⎠    ⎝2
#
#                   ⎛__⎞    ⎛__⎞    ⎛__⎞                                      ⎛_
#   ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₃⎟      ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ
# os⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜─
#   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠      ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2
#
# ⎛__⎞                    ⎛__⎞    ⎛__⎞    ⎛__⎞
# ⎜θ₄⎟    ⎛θ₁⎞    ⎛θ₃⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₃⎟    ⅈ⋅φ₂    ⎛θ₂⎞    ⎛θ₁⎞    ⎛θ₃⎞
# ⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅c
# ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠            ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
# ⎛__⎞                    ⎛__⎞    ⎛__⎞    ⎛__⎞
# ⎜θ₄⎟    ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₃⎟    ⅈ⋅φ₁    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞
# ⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅c
# ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠            ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#               ⎛__⎞            ⎛__⎞    ⎛__⎞    ⎛__⎞
# ₂⎞    ⎛θ₄⎞    ⎜θ₄⎟    ⎛θ₃⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₃⎟    ⅈ⋅φ₁  ⅈ⋅φ₂    ⎛θ₁⎞    ⎛θ
# ─⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅sin⎜──⎟⋅sin⎜─
#  ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                  ⎝2 ⎠    ⎝2
#
# _⎞    ⎛__⎞    ⎛__⎞    ⎛__⎞
# ₁⎟    ⎜θ₂⎟    ⎜θ₃⎟    ⎜θ₄⎟                                                   ⅈ
# ─⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟                                                  ℯ
#  ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#           ⎛__⎞    ⎛__⎞    ⎛__⎞    ⎛__⎞
#   ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₃⎟    ⎜θ₄⎟                           ⅈ⋅φ₂  ⅈ⋅φ₃  ⅈ
# os⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟                          ℯ    ⋅ℯ    ⋅ℯ
#   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#           ⎛__⎞    ⎛__⎞    ⎛__⎞    ⎛__⎞
#   ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₃⎟    ⎜θ₄⎟                           ⅈ⋅φ₁  ⅈ⋅φ₃  ⅈ
# os⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟                          ℯ    ⋅ℯ    ⋅ℯ
#   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#                       ⎛__⎞    ⎛__⎞    ⎛__⎞    ⎛__⎞
# ₂⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₃⎟    ⎜θ₄⎟   ⅈ⋅φ₁  ⅈ⋅φ₂  ⅈ⋅φ₃  ⅈ⋅φ₄  -
# ─⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟  ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ
#  ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#               __     __     __                    ⎛__⎞    ⎛__⎞    ⎛__⎞
# ⋅φ₃  ⅈ⋅φ₄  -ⅈ⋅φ₂  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⎜θ₄⎟    ⎛θ₁⎞
#    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟
#                                   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#         __     __     __                            ⎛__⎞    ⎛__⎞    ⎛__⎞
# ⋅φ₄  -ⅈ⋅φ₂  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₂⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⎜θ₄⎟    ⎛θ
#    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜─
#                             ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2
#
#         __     __     __                            ⎛__⎞    ⎛__⎞    ⎛__⎞
# ⋅φ₄  -ⅈ⋅φ₂  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⎜θ₄⎟    ⎛θ
#    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜─
#                             ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2
#
#   __     __     __                                    ⎛__⎞    ⎛__⎞    ⎛__⎞
# ⅈ⋅φ₂  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⎜θ₄⎟
#     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos
#                       ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#             ⎛__⎞             __     __            ⎛__⎞    ⎛__⎞
#     ⎛θ₂⎞    ⎜θ₁⎟    ⅈ⋅φ₃  -ⅈ⋅φ₂  -ⅈ⋅φ₃    ⎛θ₃⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⎛θ₁⎞    ⎛θ₂⎞
# ⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟
#     ⎝2 ⎠    ⎝2 ⎠                          ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#       ⎛__⎞                   __     __                    ⎛__⎞    ⎛__⎞
# ₁⎞    ⎜θ₁⎟    ⅈ⋅φ₂  ⅈ⋅φ₃  -ⅈ⋅φ₂  -ⅈ⋅φ₃    ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⎛θ₁⎞
# ─⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟
#  ⎠    ⎝2 ⎠                                ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#       ⎛__⎞                   __     __                    ⎛__⎞    ⎛__⎞
# ₂⎞    ⎜θ₁⎟    ⅈ⋅φ₁  ⅈ⋅φ₃  -ⅈ⋅φ₂  -ⅈ⋅φ₃    ⎛θ₁⎞    ⎛θ₃⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⎛θ₂⎞
# ─⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟
#  ⎠    ⎝2 ⎠                                ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
# ⎛__⎞                         __     __                            ⎛__⎞    ⎛__⎞
# ⎜θ₁⎟    ⅈ⋅φ₁  ⅈ⋅φ₂  ⅈ⋅φ₃  -ⅈ⋅φ₂  -ⅈ⋅φ₃    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₂⎟    ⎜θ₃⎟
# ⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟
# ⎝2 ⎠                                      ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#             ⎛__⎞    ⎛__⎞             __     __            ⎛__⎞    ⎛__⎞
#     ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₄⎟    ⅈ⋅φ₄  -ⅈ⋅φ₂  -ⅈ⋅φ₄    ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₄⎟    ⎛θ₁⎞
# ⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟
#     ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                          ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#             ⎛__⎞    ⎛__⎞                   __     __                    ⎛__⎞
#     ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₄⎟    ⅈ⋅φ₂  ⅈ⋅φ₄  -ⅈ⋅φ₂  -ⅈ⋅φ₄    ⎛θ₂⎞    ⎛θ₄⎞    ⎜θ₂⎟
# ⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅s
#     ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                                ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#             ⎛__⎞    ⎛__⎞                   __     __                    ⎛__⎞
#     ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₄⎟    ⅈ⋅φ₁  ⅈ⋅φ₄  -ⅈ⋅φ₂  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ₄⎞    ⎜θ₂⎟
# ⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅s
#     ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                                ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#             ⎛__⎞    ⎛__⎞                         __     __
#     ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₄⎟    ⅈ⋅φ₁  ⅈ⋅φ₂  ⅈ⋅φ₄  -ⅈ⋅φ₂  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ₂⎞
# ⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin
#     ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                                      ⎝2 ⎠    ⎝2 ⎠
#
#                     ⎛__⎞    ⎛__⎞       __    ⎛__⎞
#     ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₁⎟    ⎜θ₃⎟    -ⅈ⋅φ₂    ⎜θ₂⎟    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞    ⎛
# ⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ     ⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜
#     ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠             ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝
#
#   ⎛__⎞                    ⎛__⎞    ⎛__⎞             __            ⎛__⎞
#   ⎜θ₄⎟    ⎛θ₁⎞    ⎛θ₃⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⅈ⋅φ₂  -ⅈ⋅φ₂    ⎛θ₂⎞    ⎜θ₂⎟    ⎛θ₁⎞
# in⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅
#   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#   ⎛__⎞                    ⎛__⎞    ⎛__⎞             __            ⎛__⎞
#   ⎜θ₄⎟    ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⅈ⋅φ₁  -ⅈ⋅φ₂    ⎛θ₁⎞    ⎜θ₂⎟    ⎛θ₂⎞
# in⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅
#   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#         ⎛__⎞    ⎛__⎞            ⎛__⎞    ⎛__⎞                   __
# ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₄⎟    ⎛θ₃⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⅈ⋅φ₁  ⅈ⋅φ₂  -ⅈ⋅φ₂    ⎛θ₁⎞    ⎛
# ⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜
# ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                         ⎝2 ⎠    ⎝
#
#        ⎛__⎞    ⎛__⎞    ⎛__⎞
# θ₄⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⎜θ₄⎟
# ──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟                                                  ℯ
# 2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#                    ⎛__⎞    ⎛__⎞    ⎛__⎞
#    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⎜θ₄⎟                           ⅈ⋅φ₂  ⅈ⋅φ₃
# cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟                          ℯ    ⋅ℯ    ⋅ℯ
#    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#                    ⎛__⎞    ⎛__⎞    ⎛__⎞
#    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⎜θ₄⎟                           ⅈ⋅φ₁  ⅈ⋅φ₃
# cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟                          ℯ    ⋅ℯ    ⋅ℯ
#    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#        ⎛__⎞                    ⎛__⎞    ⎛__⎞    ⎛__⎞
# θ₂⎞    ⎜θ₂⎟    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⎜θ₄⎟   ⅈ⋅φ₁  ⅈ⋅φ₂  ⅈ⋅φ₃  ⅈ⋅φ₄
# ──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟  ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ
# 2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#                __     __     __                    ⎛__⎞    ⎛__⎞    ⎛__⎞
# ⅈ⋅φ₃  ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⎜θ₄⎟    ⎛θ₁
#     ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──
#                                    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2
#
#          __     __     __                            ⎛__⎞    ⎛__⎞    ⎛__⎞
# ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₂⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⎜θ₄⎟    ⎛
#     ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜
#                              ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝
#
#          __     __     __                            ⎛__⎞    ⎛__⎞    ⎛__⎞
# ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⎜θ₄⎟    ⎛
#     ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜
#                              ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝
#
#    __     __     __                                    ⎛__⎞    ⎛__⎞    ⎛__⎞
# -ⅈ⋅φ₁  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⎜θ₄⎟
#      ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅co
#                        ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#              ⎛__⎞             __     __            ⎛__⎞    ⎛__⎞
# ⎞    ⎛θ₂⎞    ⎜θ₂⎟    ⅈ⋅φ₃  -ⅈ⋅φ₁  -ⅈ⋅φ₃    ⎛θ₃⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⎛θ₁⎞    ⎛θ₂
# ⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──
# ⎠    ⎝2 ⎠    ⎝2 ⎠                          ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2
#
#        ⎛__⎞                   __     __                    ⎛__⎞    ⎛__⎞
# θ₁⎞    ⎜θ₂⎟    ⅈ⋅φ₂  ⅈ⋅φ₃  -ⅈ⋅φ₁  -ⅈ⋅φ₃    ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⎛θ₁
# ──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──
# 2 ⎠    ⎝2 ⎠                                ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2
#
#        ⎛__⎞                   __     __                    ⎛__⎞    ⎛__⎞
# θ₂⎞    ⎜θ₂⎟    ⅈ⋅φ₁  ⅈ⋅φ₃  -ⅈ⋅φ₁  -ⅈ⋅φ₃    ⎛θ₁⎞    ⎛θ₃⎞    ⎜θ₁⎟    ⎜θ₃⎟    ⎛θ₂
# ──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──
# 2 ⎠    ⎝2 ⎠                                ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2
#
#  ⎛__⎞                         __     __                            ⎛__⎞    ⎛__
#  ⎜θ₂⎟    ⅈ⋅φ₁  ⅈ⋅φ₂  ⅈ⋅φ₃  -ⅈ⋅φ₁  -ⅈ⋅φ₃    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₁⎟    ⎜θ₃
# s⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──
#  ⎝2 ⎠                                      ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2
#
#              ⎛__⎞    ⎛__⎞             __     __            ⎛__⎞    ⎛__⎞
# ⎞    ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₄⎟    ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₄    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₄⎟    ⎛θ₁
# ⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──
# ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                          ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2
#
#              ⎛__⎞    ⎛__⎞                   __     __                    ⎛__⎞
# ⎞    ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₄⎟    ⅈ⋅φ₂  ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₄    ⎛θ₂⎞    ⎛θ₄⎞    ⎜θ₁⎟
# ⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅
# ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                                ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#              ⎛__⎞    ⎛__⎞                   __     __                    ⎛__⎞
# ⎞    ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₄⎟    ⅈ⋅φ₁  ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ₄⎞    ⎜θ₁⎟
# ⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅
# ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                                ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
# ⎞            ⎛__⎞    ⎛__⎞                         __     __
# ⎟    ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₄⎟    ⅈ⋅φ₁  ⅈ⋅φ₂  ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ₂⎞
# ⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅si
# ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                                      ⎝2 ⎠    ⎝2 ⎠
#
#                      ⎛__⎞    ⎛__⎞       __    ⎛__⎞
# ⎞    ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₂⎟    ⎜θ₃⎟    -ⅈ⋅φ₁    ⎜θ₁⎟    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞
# ⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ     ⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos
# ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠             ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#    ⎛__⎞                    ⎛__⎞    ⎛__⎞             __            ⎛__⎞
#    ⎜θ₄⎟    ⎛θ₁⎞    ⎛θ₃⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⅈ⋅φ₂  -ⅈ⋅φ₁    ⎛θ₂⎞    ⎜θ₁⎟    ⎛θ₁⎞
# sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟
#    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#    ⎛__⎞                    ⎛__⎞    ⎛__⎞             __            ⎛__⎞
#    ⎜θ₄⎟    ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⅈ⋅φ₁  -ⅈ⋅φ₁    ⎛θ₁⎞    ⎜θ₁⎟    ⎛θ₂⎞
# sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟
#    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                   ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#          ⎛__⎞    ⎛__⎞            ⎛__⎞    ⎛__⎞                   __
#  ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₄⎟    ⎛θ₃⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⅈ⋅φ₁  ⅈ⋅φ₂  -ⅈ⋅φ₁    ⎛θ₁⎞
# n⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅sin⎜──⎟⋅sin
#  ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                         ⎝2 ⎠
#
#         ⎛__⎞    ⎛__⎞    ⎛__⎞
# ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⎜θ₄⎟
# ⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟
# ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#                     ⎛__⎞    ⎛__⎞    ⎛__⎞
#     ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⎜θ₄⎟                           ⅈ⋅φ₂  ⅈ⋅φ₃
# ⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟                          ℯ    ⋅ℯ    ⋅
#     ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#                     ⎛__⎞    ⎛__⎞    ⎛__⎞
#     ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⎜θ₄⎟                           ⅈ⋅φ₁  ⅈ⋅φ₃
# ⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟                          ℯ    ⋅ℯ    ⋅
#     ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#         ⎛__⎞                    ⎛__⎞    ⎛__⎞    ⎛__⎞
# ⎛θ₂⎞    ⎜θ₁⎟    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₂⎟    ⎜θ₃⎟    ⎜θ₄⎟   ⅈ⋅φ₁  ⅈ⋅φ₂  ⅈ⋅φ₃  ⅈ⋅φ₄
# ⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟  ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ    ⋅
# ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#                 __     __     __     __                    ⎛__⎞    ⎛__⎞    ⎛__
#  ⅈ⋅φ₃  ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₂  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₃
# ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──
#                                            ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2
#
#           __     __     __     __                            ⎛__⎞    ⎛__⎞    ⎛
#  ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₂  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₂⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜
# ℯ    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜
#                                      ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝
#
#           __     __     __     __                            ⎛__⎞    ⎛__⎞    ⎛
#  ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₂  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜
# ℯ    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜
#                                      ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝
#
#     __     __     __     __                                    ⎛__⎞    ⎛__⎞
#  -ⅈ⋅φ₁  -ⅈ⋅φ₂  -ⅈ⋅φ₃  -ⅈ⋅φ₄    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟
# ℯ     ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅si
#                                ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
# ⎞    ⎛__⎞                             __     __     __            ⎛__⎞    ⎛__⎞
# ⎟    ⎜θ₄⎟    ⎛θ₁⎞    ⎛θ₂⎞    ⅈ⋅φ₃  -ⅈ⋅φ₁  -ⅈ⋅φ₂  -ⅈ⋅φ₃    ⎛θ₃⎞    ⎜θ₁⎟    ⎜θ₂⎟
# ⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟
# ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                                 ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
# __⎞    ⎛__⎞                           __     __     __                    ⎛__⎞
# θ₃⎟    ⎜θ₄⎟    ⎛θ₁⎞    ⅈ⋅φ₂  ⅈ⋅φ₃  -ⅈ⋅φ₁  -ⅈ⋅φ₂  -ⅈ⋅φ₃    ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₁⎟
# ──⎟⋅sin⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟
# 2 ⎠    ⎝2 ⎠    ⎝2 ⎠                                       ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
# __⎞    ⎛__⎞                           __     __     __                    ⎛__⎞
# θ₃⎟    ⎜θ₄⎟    ⎛θ₂⎞    ⅈ⋅φ₁  ⅈ⋅φ₃  -ⅈ⋅φ₁  -ⅈ⋅φ₂  -ⅈ⋅φ₃    ⎛θ₁⎞    ⎛θ₃⎞    ⎜θ₁⎟
# ──⎟⋅sin⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟
# 2 ⎠    ⎝2 ⎠    ⎝2 ⎠                                       ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#  ⎛__⎞    ⎛__⎞                         __     __     __
#  ⎜θ₃⎟    ⎜θ₄⎟    ⅈ⋅φ₁  ⅈ⋅φ₂  ⅈ⋅φ₃  -ⅈ⋅φ₁  -ⅈ⋅φ₂  -ⅈ⋅φ₃    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞
# n⎜──⎟⋅sin⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟
#  ⎝2 ⎠    ⎝2 ⎠                                             ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#     ⎛__⎞                            ⎛__⎞             __     __     __
#     ⎜θ₃⎟    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₄⎞    ⎜θ₄⎟    ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₂  -ⅈ⋅φ₄    ⎛θ₄⎞
# ⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅
#     ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                                 ⎝2 ⎠
#
#     ⎛__⎞    ⎛__⎞                    ⎛__⎞                   __     __     __
#     ⎜θ₂⎟    ⎜θ₃⎟    ⎛θ₁⎞    ⎛θ₄⎞    ⎜θ₄⎟    ⅈ⋅φ₂  ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₂  -ⅈ⋅φ₄
# ⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅si
#     ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#     ⎛__⎞    ⎛__⎞                    ⎛__⎞                   __     __     __
#     ⎜θ₂⎟    ⎜θ₃⎟    ⎛θ₂⎞    ⎛θ₄⎞    ⎜θ₄⎟    ⅈ⋅φ₁  ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₂  -ⅈ⋅φ₄
# ⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅ℯ     ⋅si
#     ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#     ⎛__⎞    ⎛__⎞    ⎛__⎞            ⎛__⎞                         __     __
#     ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₃⎟    ⎛θ₄⎞    ⎜θ₄⎟    ⅈ⋅φ₁  ⅈ⋅φ₂  ⅈ⋅φ₄  -ⅈ⋅φ₁  -ⅈ⋅φ₂  -ⅈ
# ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ    ⋅ℯ    ⋅ℯ     ⋅ℯ     ⋅ℯ
#     ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#    ⎛__⎞    ⎛__⎞    ⎛__⎞                            ⎛__⎞       __     __    ⎛__
#    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₄⎟    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₃⎟    -ⅈ⋅φ₁  -ⅈ⋅φ₂    ⎜θ₁
# sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ     ⋅ℯ     ⋅sin⎜──
#    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠                    ⎝2
#
#                  ⎛__⎞    ⎛__⎞    ⎛__⎞                    ⎛__⎞             __
#  ⎛θ₂⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₄⎟    ⎛θ₁⎞    ⎛θ₃⎞    ⎜θ₃⎟    ⅈ⋅φ₂  -ⅈ⋅φ₁
# n⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅ℯ
#  ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#                  ⎛__⎞    ⎛__⎞    ⎛__⎞                    ⎛__⎞             __
#  ⎛θ₁⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₄⎟    ⎛θ₂⎞    ⎛θ₃⎞    ⎜θ₃⎟    ⅈ⋅φ₁  -ⅈ⋅φ₁
# n⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ     ⋅ℯ
#  ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#  __                            ⎛__⎞    ⎛__⎞    ⎛__⎞            ⎛__⎞
# ⋅φ₄    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₄⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎜θ₄⎟    ⎛θ₃⎞    ⎜θ₃⎟    ⅈ⋅φ₁  ⅈ
#    ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟ + ℯ    ⋅ℯ
#        ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
# ⎞    ⎛__⎞                                    ⎛__⎞    ⎛__⎞
# ⎟    ⎜θ₂⎟    ⎛θ₁⎞    ⎛θ₂⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₃⎟    ⎜θ₄⎟
# ⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟
# ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#    __            ⎛__⎞    ⎛__⎞                            ⎛__⎞    ⎛__⎞
# -ⅈ⋅φ₂    ⎛θ₂⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎛θ₁⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₃⎟    ⎜θ₄⎟
#      ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟
#          ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#    __            ⎛__⎞    ⎛__⎞                            ⎛__⎞    ⎛__⎞
# -ⅈ⋅φ₂    ⎛θ₁⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎛θ₂⎞    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₃⎟    ⎜θ₄⎟
#      ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟
#          ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠
#
#         __     __                    ⎛__⎞    ⎛__⎞                    ⎛__⎞    ⎛
# ⋅φ₂  -ⅈ⋅φ₁  -ⅈ⋅φ₂    ⎛θ₁⎞    ⎛θ₂⎞    ⎜θ₁⎟    ⎜θ₂⎟    ⎛θ₃⎞    ⎛θ₄⎞    ⎜θ₃⎟    ⎜
#    ⋅ℯ     ⋅ℯ     ⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜──⎟⋅cos⎜
#                      ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝2 ⎠    ⎝
#
#    ⎤
#    ⎥
#    ⎥
#    ⎥
#    ⎥
#    ⎥
#    ⎥
#    ⎥
#    ⎥
#    ⎥
#    ⎥
#    ⎥
#    ⎥
#    ⎥
#    ⎥
# __⎞⎥
# θ₄⎟⎥
# ──⎟⎥
# 2 ⎠⎦

# %%
from sympy import pprint

# Iterate through the reduced density matrix and print each element
for i in range(4):
    for j in range(4):
        print(f"Element ({i}, {j}):")
        print(rho_12[i, j])
        print("\n" + "-"*50 + "\n")
# Out:
# Element (0, 0):
# exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2) + exp(I*phi_3)*exp(-I*conjugate(phi_3))*sin(theta_3/2)*sin(conjugate(theta_3)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_4)/2) + exp(I*phi_4)*exp(-I*conjugate(phi_4))*sin(theta_4/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2) + cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (0, 1):
# exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(conjugate(theta_1)/2) + exp(I*phi_3)*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*sin(theta_3/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_4)/2) + exp(I*phi_4)*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_4))*sin(theta_4/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_3)/2) + exp(-I*conjugate(phi_2))*sin(conjugate(theta_2)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (0, 2):
# exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(conjugate(theta_2)/2) + exp(I*phi_3)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_3))*sin(theta_3/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_3)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_4/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_4)/2) + exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_4))*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2) + exp(-I*conjugate(phi_1))*sin(conjugate(theta_1)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (0, 3):
# exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(theta_2/2) + exp(I*phi_3)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*sin(theta_3/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_4/2)*cos(conjugate(theta_4)/2) + exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_4))*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(conjugate(theta_3)/2) + exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (1, 0):
# exp(I*phi_2)*exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2) + exp(I*phi_2)*exp(I*phi_3)*exp(-I*conjugate(phi_3))*sin(theta_2/2)*sin(theta_3/2)*sin(conjugate(theta_3)/2)*cos(theta_1/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_4)/2) + exp(I*phi_2)*exp(I*phi_4)*exp(-I*conjugate(phi_4))*sin(theta_2/2)*sin(theta_4/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(theta_3/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2) + exp(I*phi_2)*sin(theta_2/2)*cos(theta_1/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (1, 1):
# exp(I*phi_2)*exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(conjugate(theta_1)/2) + exp(I*phi_2)*exp(I*phi_3)*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*sin(theta_2/2)*sin(theta_3/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*cos(theta_1/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_4)/2) + exp(I*phi_2)*exp(I*phi_4)*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_4))*sin(theta_2/2)*sin(theta_4/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(theta_3/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_3)/2) + exp(I*phi_2)*exp(-I*conjugate(phi_2))*sin(theta_2/2)*sin(conjugate(theta_2)/2)*cos(theta_1/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (1, 2):
# exp(I*phi_2)*exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(conjugate(theta_2)/2) + exp(I*phi_2)*exp(I*phi_3)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_3))*sin(theta_2/2)*sin(theta_3/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_3)/2)*cos(theta_1/2)*cos(theta_4/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_4)/2) + exp(I*phi_2)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_4))*sin(theta_2/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(theta_3/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2) + exp(I*phi_2)*exp(-I*conjugate(phi_1))*sin(theta_2/2)*sin(conjugate(theta_1)/2)*cos(theta_1/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (1, 3):
# exp(I*phi_2)*exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2) + exp(I*phi_2)*exp(I*phi_3)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*sin(theta_2/2)*sin(theta_3/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*cos(theta_1/2)*cos(theta_4/2)*cos(conjugate(theta_4)/2) + exp(I*phi_2)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_4))*sin(theta_2/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_4)/2)*cos(theta_1/2)*cos(theta_3/2)*cos(conjugate(theta_3)/2) + exp(I*phi_2)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*sin(theta_2/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*cos(theta_1/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (2, 0):
# exp(I*phi_1)*exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(theta_2/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2) + exp(I*phi_1)*exp(I*phi_3)*exp(-I*conjugate(phi_3))*sin(theta_1/2)*sin(theta_3/2)*sin(conjugate(theta_3)/2)*cos(theta_2/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_4)/2) + exp(I*phi_1)*exp(I*phi_4)*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_4/2)*sin(conjugate(theta_4)/2)*cos(theta_2/2)*cos(theta_3/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2) + exp(I*phi_1)*sin(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (2, 1):
# exp(I*phi_1)*exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(theta_2/2)*cos(conjugate(theta_1)/2) + exp(I*phi_1)*exp(I*phi_3)*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*sin(theta_1/2)*sin(theta_3/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*cos(theta_2/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_4)/2) + exp(I*phi_1)*exp(I*phi_4)*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_4/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_4)/2)*cos(theta_2/2)*cos(theta_3/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_3)/2) + exp(I*phi_1)*exp(-I*conjugate(phi_2))*sin(theta_1/2)*sin(conjugate(theta_2)/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (2, 2):
# exp(I*phi_1)*exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(theta_2/2)*cos(conjugate(theta_2)/2) + exp(I*phi_1)*exp(I*phi_3)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_3))*sin(theta_1/2)*sin(theta_3/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_3)/2)*cos(theta_2/2)*cos(theta_4/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_4)/2) + exp(I*phi_1)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_4)/2)*cos(theta_2/2)*cos(theta_3/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2) + exp(I*phi_1)*exp(-I*conjugate(phi_1))*sin(theta_1/2)*sin(conjugate(theta_1)/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (2, 3):
# exp(I*phi_1)*exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(theta_2/2) + exp(I*phi_1)*exp(I*phi_3)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*sin(theta_1/2)*sin(theta_3/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*cos(theta_2/2)*cos(theta_4/2)*cos(conjugate(theta_4)/2) + exp(I*phi_1)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_4)/2)*cos(theta_2/2)*cos(theta_3/2)*cos(conjugate(theta_3)/2) + exp(I*phi_1)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*sin(theta_1/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (3, 0):
# exp(I*phi_1)*exp(I*phi_2)*exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2) + exp(I*phi_1)*exp(I*phi_2)*exp(I*phi_3)*exp(-I*conjugate(phi_3))*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(conjugate(theta_3)/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_4)/2) + exp(I*phi_1)*exp(I*phi_2)*exp(I*phi_4)*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_2/2)*sin(theta_4/2)*sin(conjugate(theta_4)/2)*cos(theta_3/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2) + exp(I*phi_1)*exp(I*phi_2)*sin(theta_1/2)*sin(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (3, 1):
# exp(I*phi_1)*exp(I*phi_2)*exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(conjugate(theta_1)/2) + exp(I*phi_1)*exp(I*phi_2)*exp(I*phi_3)*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_4)/2) + exp(I*phi_1)*exp(I*phi_2)*exp(I*phi_4)*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_2/2)*sin(theta_4/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_4)/2)*cos(theta_3/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_3)/2) + exp(I*phi_1)*exp(I*phi_2)*exp(-I*conjugate(phi_2))*sin(theta_1/2)*sin(theta_2/2)*sin(conjugate(theta_2)/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_1)/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (3, 2):
# exp(I*phi_1)*exp(I*phi_2)*exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2)*cos(conjugate(theta_2)/2) + exp(I*phi_1)*exp(I*phi_2)*exp(I*phi_3)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_3))*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_3)/2)*cos(theta_4/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_4)/2) + exp(I*phi_1)*exp(I*phi_2)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_2/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_4)/2)*cos(theta_3/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2) + exp(I*phi_1)*exp(I*phi_2)*exp(-I*conjugate(phi_1))*sin(theta_1/2)*sin(theta_2/2)*sin(conjugate(theta_1)/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_2)/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------
#
# Element (3, 3):
# exp(I*phi_1)*exp(I*phi_2)*exp(I*phi_3)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*sin(conjugate(theta_4)/2) + exp(I*phi_1)*exp(I*phi_2)*exp(I*phi_3)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_3))*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_3)/2)*cos(theta_4/2)*cos(conjugate(theta_4)/2) + exp(I*phi_1)*exp(I*phi_2)*exp(I*phi_4)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*exp(-I*conjugate(phi_4))*sin(theta_1/2)*sin(theta_2/2)*sin(theta_4/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*sin(conjugate(theta_4)/2)*cos(theta_3/2)*cos(conjugate(theta_3)/2) + exp(I*phi_1)*exp(I*phi_2)*exp(-I*conjugate(phi_1))*exp(-I*conjugate(phi_2))*sin(theta_1/2)*sin(theta_2/2)*sin(conjugate(theta_1)/2)*sin(conjugate(theta_2)/2)*cos(theta_3/2)*cos(theta_4/2)*cos(conjugate(theta_3)/2)*cos(conjugate(theta_4)/2)
#
# --------------------------------------------------

# %%
import numpy as np

# Example values (in radians)
vals = {
    theta[0]: np.pi/3, phi[0]: np.pi/4,
    theta[1]: np.pi/2, phi[1]: np.pi/3,
    theta[2]: np.pi/4, phi[2]: np.pi/6,
    theta[3]: np.pi/6, phi[3]: np.pi/2,
}

# Evaluate the matrix numerically with substitutions
rho_numeric = rho_12.evalf(subs=vals)

# Convert to NumPy array (complex dtype)
rho_np = np.array(rho_numeric.tolist(), dtype=np.complex128)

# Optional: print or use it
print(rho_np)
# Out:
# [[ 0.375     -1.95625174e-29j  0.1875    -3.24759526e-01j
#    0.15309311-1.53093109e-01j -0.05603597-2.09129076e-01j]
#  [ 0.1875    +3.24759526e-01j  0.375     -3.40963734e-28j
#    0.20912908+5.60359670e-02j  0.15309311-1.53093109e-01j]
#  [ 0.15309311+1.53093109e-01j  0.20912908-5.60359670e-02j
#    0.125     +3.53351005e-28j  0.0625    -1.08253175e-01j]
#  [-0.05603597+2.09129076e-01j  0.15309311+1.53093109e-01j
#    0.0625    +1.08253175e-01j  0.125     +3.14276310e-27j]]
