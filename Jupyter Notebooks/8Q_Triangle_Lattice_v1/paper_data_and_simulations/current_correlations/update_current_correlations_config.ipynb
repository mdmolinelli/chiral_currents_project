# %%
import os
import shutil
from datetime import datetime

import json
import matplotlib.pyplot as plt
import numpy as np

# %%
def backup_config(config_filename):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename_only = os.path.basename(config_filename)
    name, ext = os.path.splitext(filename_only)
    backup_name = f"{name}_{timestamp}{ext}"
    backup_path = os.path.join('config_backups', backup_name)
    shutil.copy2(config_filename, backup_path)

def update_config(config_filename, new_data, keys, save_backup=True):

    if save_backup:
        backup_config(config_filename)

    with open(config_filename, 'r') as f:
        config = json.load(f)
    
    data = config
    for i in range(len(keys)-1):
        key = keys[i]

        if key not in data:
            data[key] = {}
        data = data[key]

    data[keys[-1]] = new_data


    
    with open(config_filename, 'w') as f:
        json.dump(config, f, indent=4)

def read_config(config_filename, keys=None):
    with open(config_filename, 'r') as f:
        config = json.load(f)
    
    data = config
    if keys is not None:
        for i in range(len(keys)-1):
            key = keys[i]
            data = data[key]

        return data[keys[-1]]
    else:
        return data
        
def remove_field(config_filename, keys, save_backup=False):
    if save_backup:
        backup_config(config_filename)

    with open(config_filename, 'r') as f:
        config = json.load(f)
    
    data = config
    for i in range(len(keys)-1):
        key = keys[i]
        data = data[key]

    del data[keys[-1]]
    
    with open(config_filename, 'w') as f:
        json.dump(config, f, indent=4)

# %%
# ### testing

# update_config(config_filename, {1:2, 3:5}, ('coupling_point_1', 'data_config', 'test'))

# %%
config_filename = 'current_correlations_config.json'

# %%
coupling_point = 'coupling_point_5'
eigenstate = 'highest'

# %% [markdown]
# # 1. Experimental Parameters

# %%
# # ### update coupling strengths

# J_dict = {}

# J_dict['J_13'] = 13.41
# J_dict['J_24'] = 13.59
# J_dict['J_35'] = 12.67
# J_dict['J_46'] = 12.94
# J_dict['J_57'] = 12.67
# J_dict['J_68'] = 12.60

# J_dict['J_12'] = -6.30
# J_dict['J_23'] = -6.78
# J_dict['J_34'] = -6.69
# J_dict['J_45'] = -6.78
# J_dict['J_56'] = -6.59
# J_dict['J_67'] = -6.74
# J_dict['J_78'] = -6.39



# keys = (coupling_point, 'coupling')

# update_config(config_filename, J_dict, keys, save_backup=False)

# J_error_dict = {}

# J_error_dict['J_13'] = 0.03
# J_error_dict['J_24'] = 0.04
# J_error_dict['J_35'] = 0.03
# J_error_dict['J_46'] = 0.04
# J_error_dict['J_57'] = 0.03
# J_error_dict['J_68'] = 0.05

# J_error_dict['J_12'] = 0.04
# J_error_dict['J_23'] = 0.04
# J_error_dict['J_34'] = 0.06
# J_error_dict['J_45'] = 0.01
# J_error_dict['J_56'] = 0.04
# J_error_dict['J_67'] = 0.01
# J_error_dict['J_78'] = 0.01


# keys = (coupling_point, 'coupling_error')

# update_config(config_filename, J_error_dict, keys)

# %%
# # ### update T2s, units of mus

# T2_dict = {}


# T2_dict['T2_1'] = 1.889
# T2_dict['T2_2'] = 1.049
# T2_dict['T2_3'] = 3.371
# T2_dict['T2_4'] = 0.555
# T2_dict['T2_5'] = 3.472
# T2_dict['T2_6'] = 1.
# T2_dict['T2_7'] = 1.604
# T2_dict['T2_8'] = 1.599


# keys = (coupling_point, 'T2s')

# update_config(config_filename, T2_dict, keys)

# %%
# ### update measurement detunings


# correlation_pair_to_measurement_detunings = {}


# # 12-xy
# detuning_1234 = np.array([-200., -200., 400., 400., -100., -100., 300., 300.]) * 2 * np.pi  # MHz
# detuning_1245 = np.array([100., 100., 350., -200., -200., 346.5, 347., 370.7]) * 2 * np.pi
# detuning_1256 = detuning_1234
# detuning_1267 = np.array([200., 200., -347.3, -303.9, -309.6, 300., 300., -300.1]) * 2 * np.pi
# detuning_1278 = detuning_1234

# # 23-xy
# detuning_2345 = np.array([-288.1, 200., 200., -150., -150., 305.3, 300., -300.1]) * 2 * np.pi  # MHz
# detuning_2356 = np.array([-288.1, 300., 300., -303.9, 0., 0., -363.1, -300.1]) * 2 * np.pi
# detuning_2367 = detuning_2345
# detuning_2378 = np.array([-288.1, 300., 300., -303.9, -309.6, -308.1, -25., -25.]) * 2 * np.pi

# # 34-xy
# detuning_3456 = detuning_1234
# detuning_3467 = np.array([-288.1, -296., 300., 300., -309.6, 0., 0., -300.1]) * 2 * np.pi
# detuning_3478 = detuning_1234

# # 45-xy
# detuning_4567 = detuning_2345
# detuning_4578 = np.array([-288.1, 300., 300., 0., 0., 300., -250., -250.]) * 2 * np.pi

# # 56-78
# detuning_5678 = detuning_1234



# correlation_pair_to_measurement_detunings[((1, 2), (3, 4))] = detuning_1234
# correlation_pair_to_measurement_detunings[((1, 2), (4, 5))] = detuning_1245
# correlation_pair_to_measurement_detunings[((1, 2), (5, 6))] = detuning_1256
# correlation_pair_to_measurement_detunings[((1, 2), (6, 7))] = detuning_1267
# correlation_pair_to_measurement_detunings[((1, 2), (7, 8))] = detuning_1278

# correlation_pair_to_measurement_detunings[((2, 3), (4, 5))] = detuning_2345
# correlation_pair_to_measurement_detunings[((2, 3), (5, 6))] = detuning_2356
# correlation_pair_to_measurement_detunings[((2, 3), (6, 7))] = detuning_2367
# correlation_pair_to_measurement_detunings[((2, 3), (7, 8))] = detuning_2378

# correlation_pair_to_measurement_detunings[((3, 4), (5, 6))] = detuning_3456
# correlation_pair_to_measurement_detunings[((3, 4), (6, 7))] = detuning_3467
# correlation_pair_to_measurement_detunings[((3, 4), (7, 8))] = detuning_3478

# correlation_pair_to_measurement_detunings[((4, 5), (6, 7))] = detuning_4567
# correlation_pair_to_measurement_detunings[((4, 5), (7, 8))] = detuning_4578

# correlation_pair_to_measurement_detunings[((5, 6), (7, 8))] = detuning_5678


# keys = (coupling_point, 'data_config')


# backup_config(config_filename)
# for correlation_pair in correlation_pair_to_measurement_detunings:
#     correlation_pair_key = str(correlation_pair)
#     print(correlation_pair_key)
#     measurement_detuning_list = list(correlation_pair_to_measurement_detunings[correlation_pair])
#     update_config(config_filename, measurement_detuning_list, keys + (correlation_pair_key, 'measurement_detunings'), save_backup=False)
# Out:
# ((1, 2), (3, 4))
# ((1, 2), (4, 5))
# ((1, 2), (5, 6))
# ((1, 2), (6, 7))
# ((1, 2), (7, 8))
# ((2, 3), (4, 5))
# ((2, 3), (5, 6))
# ((2, 3), (6, 7))
# ((2, 3), (7, 8))
# ((3, 4), (5, 6))
# ((3, 4), (6, 7))
# ((3, 4), (7, 8))
# ((4, 5), (6, 7))
# ((4, 5), (7, 8))
# ((5, 6), (7, 8))

# %%
### add all configuration mappings
# these should be the same for all coupling points and highest or lowest eigenst

### define mapping from correlation pair to beamsplitter configuration

correlation_pair_to_configuration = {}

# all d=2,4,6 correlations
configuration_12_34_56_78 = '12-34-56-78'
correlation_pair_to_configuration[((1,2),(3,4))] = configuration_12_34_56_78
correlation_pair_to_configuration[((1,2),(5,6))] = configuration_12_34_56_78
correlation_pair_to_configuration[((1,2),(7,8))] = configuration_12_34_56_78

correlation_pair_to_configuration[((3,4),(5,6))] = configuration_12_34_56_78
correlation_pair_to_configuration[((3,4),(7,8))] = configuration_12_34_56_78

correlation_pair_to_configuration[((5,6),(7,8))] = configuration_12_34_56_78

configuration_1_23_45_67_8 = '1-23-45-67-8'
correlation_pair_to_configuration[((2,3),(4,5))] = configuration_1_23_45_67_8
correlation_pair_to_configuration[((2,3),(6,7))] = configuration_1_23_45_67_8

correlation_pair_to_configuration[((4,5),(6,7))] = configuration_1_23_45_67_8

# all d=3 correlations
correlation_pair_to_configuration[((1,2),(4,5))] = '12-3-45-6-7-8'
correlation_pair_to_configuration[((2,3),(5,6))] = '1-23-4-56-7-8'
correlation_pair_to_configuration[((3,4),(6,7))] = '1-2-34-5-67-8'
correlation_pair_to_configuration[((4,5),(7,8))] = '1-2-3-45-6-78'

# all d=5 correlations
correlation_pair_to_configuration[((1,2),(6,7))] = '12-3-4-5-67-8'
correlation_pair_to_configuration[((2,3),(7,8))] = '1-23-4-5-6-78'


keys = (coupling_point, 'data_config')

backup_config(config_filename)
for correlation_pair in correlation_pair_to_configuration:
    configuration = correlation_pair_to_configuration[correlation_pair]

    update_config(config_filename, configuration, keys + (str(correlation_pair), 'configuration'), save_backup=False)

# %%
# ### archive

#######################################################################
#######################################################################

# # coupling_point_1
# pi flux, ratio=1

# T2_dict['T2_1'] = 1.044
# T2_dict['T2_2'] = 0.959
# T2_dict['T2_3'] = 0.526
# T2_dict['T2_4'] = 1.001
# T2_dict['T2_5'] = 0.652
# T2_dict['T2_6'] = 0.587
# T2_dict['T2_7'] = 1.479
# T2_dict['T2_8'] = 0.835

# J_dict['J_13'] = -6.85
# J_dict['J_24'] = -6.76
# J_dict['J_35'] = -7.17
# J_dict['J_46'] = -7.30
# J_dict['J_57'] = -7.08
# J_dict['J_68'] = -6.82

# J_dict['J_12'] = -5.82
# J_dict['J_23'] = -5.87
# J_dict['J_34'] = -5.53
# J_dict['J_45'] = -5.79
# J_dict['J_56'] = -5.55
# J_dict['J_67'] = -5.83
# J_dict['J_78'] = -5.85

# configuration_to_date_code_highest['12-34-56-78'] = ('2025', '11', '25', '16', '54', '36') # high quality 1234
# configuration_to_date_code_highest['1-23-45-67-8'] = ('2025', '11', '25', '15', '58', '30') # high quality 2345
# configuration_to_date_code_highest['12-3-45-6-7-8'] = ('2025', '12', '02', '16', '58', '15') # high quality 1245
# configuration_to_date_code_highest['12-3-4-5-67-8'] = ('2025', '12', '04', '22', '58', '09') # high quality 1267
# configuration_to_date_code_highest['1-23-4-56-7-8'] = ('2025', '12', '04', '16', '13', '18') # high quality 2356
# configuration_to_date_code_highest['1-23-4-5-6-78'] = ('2025', '12', '05', '14', '40', '46') # high quality 2378
# configuration_to_date_code_highest['1-2-34-5-67-8'] = ('2025', '12', '05', '21', '22', '40') # high quality 3467
# configuration_to_date_code_highest['1-2-3-45-6-78'] = ('2025', '12', '07', '19', '20', '44') # high quality 4578


# configuration_to_date_code_disordered['12-34-56-78'] = ('2025', '11', '25', '11', '27', '25') # high quality 1234
# configuration_to_date_code_disordered['12-3-45-6-7-8'] = ('2025', '12', '02', '12', '13', '10') # high quality 1245
# configuration_to_date_code_disordered['12-3-4-5-67-8'] = ('2025', '12', '04', '21', '09', '03') # high quality 1267
# configuration_to_date_code_disordered['1-23-4-56-7-8'] = ('2025', '12', '04', '15', '58', '54') # high quality 2356
# configuration_to_date_code_disordered['1-23-4-5-6-78'] = ('2025', '12', '05', '14', '25', '07') # high quality 2378
# configuration_to_date_code_disordered['1-2-34-5-67-8'] = ('2025', '12', '05', '22', '04', '41') # high quality 3467
# configuration_to_date_code_disordered['1-2-3-45-6-78'] = ('2025', '12', '07', '19', '12', '54') # high quality 4578


# # 12-xy
# detuning_1234 = np.array([-200., -200.,  400.,  400., -100., -100.,  300.,  300.]) * 2 * np.pi # MHz
# detuning_1245 = np.array([ 150.,  150.,  450., -200., -200.,  450.,  450.,  450.]) * 2 * np.pi
# detuning_1256 = detuning_1234
# detuning_1267 = np.array([ 550. ,  550. , -342.6, -300.1, -304.4,  450. ,  450. , -296.8]) * 2 * np.pi
# detuning_1278 = detuning_1234
# # 23-xy
# detuning_2345 = np.array([-264.7,  500. ,  500. , -150. , -150. ,  400. ,  400. , -277.3]) * 2 * np.pi # MHz
# detuning_2356 = np.array([-264.7,  580. ,  580. , -259.9,  200. ,  200. , -339.7, -277.3]) * 2 * np.pi
# detuning_2367 = detuning_2345
# detuning_2378 = np.array([-264.7,  580. ,  580. , -259.9, -260. , -260. ,  375. ,  375. ]) * 2 * np.pi
# # 34-xy
# detuning_3456 = detuning_1234
# detuning_3467 = np.array([-264.7, -272.8,  580. ,  580. , -265.6,  200. ,  200. , -277.3]) * 2 * np.pi
# detuning_3478 = detuning_1234
# # 45-xy
# detuning_4567 = detuning_2345
# detuning_4578 = np.array([-264.7,  600. ,  600. ,  100. ,  100. ,  600. , -200. , -200. ]) * 2 * np.pi
# # 56-78
# detuning_5678 = detuning_1234

#######################################################################
#######################################################################

# # coupling_point_2
# pi flux, ratio=2

# T2_dict['T2_1'] = 2.085
# T2_dict['T2_2'] = 0.581
# T2_dict['T2_3'] = 1.976
# T2_dict['T2_4'] = 0.366
# T2_dict['T2_5'] = 2.119
# T2_dict['T2_6'] = 2.005
# T2_dict['T2_7'] = 1.727
# T2_dict['T2_8'] = 1.792


# configuration_to_date_code_highest['12-34-56-78'] = ('2025', '11', '04', '12', '54', '01')
# configuration_to_date_code_highest['1-23-45-67-8'] = ('2025', '11', '05', '11', '15', '26')
# configuration_to_date_code_highest['12-3-45-6-7-8'] = ('2025', '11', '05', '13', '16', '24')
# configuration_to_date_code_highest['12-3-4-5-67-8'] = ('2025', '11', '05', '13', '16', '24')
# configuration_to_date_code_highest['1-23-4-56-7-8'] = ('2025', '11', '05', '18', '04', '26')
# configuration_to_date_code_highest['1-23-4-5-6-78'] = ('2025', '11', '05', '21', '18', '24')
# configuration_to_date_code_highest['1-2-34-5-67-8'] = ('2025', '11', '06', '10', '52', '49')
# configuration_to_date_code_highest['1-2-3-45-6-78'] = ('2025', '11', '10', '12', '27', '11')


#######################################################################
#######################################################################

# coupling point 3
# pi flux, ratio=3

# T2_dict['T2_1'] = 1.467
# T2_dict['T2_2'] = 0.535
# T2_dict['T2_3'] = 1.543
# T2_dict['T2_4'] = 0.422
# T2_dict['T2_5'] = 2.396
# T2_dict['T2_6'] = 2.036
# T2_dict['T2_7'] = 1.371
# T2_dict['T2_8'] = 1.621

# J_dict['J_13'] = -17.31
# J_dict['J_24'] = -17.49
# J_dict['J_35'] = -17.48
# J_dict['J_46'] = -17.49
# J_dict['J_57'] = -17.38
# J_dict['J_68'] = -17.33

# J_dict['J_12'] = -5.24
# J_dict['J_23'] = -4.99
# J_dict['J_34'] = -4.51
# J_dict['J_45'] = -4.71
# J_dict['J_56'] = -4.47
# J_dict['J_67'] = -5.05
# J_dict['J_78'] = -5.25


# # 12-xy
# detuning_1234 = np.array([-200, -200.0, 400, 400.0, 50, 50, 470, 470]) * 2 * np.pi
# detuning_1245 = np.array([164, 164, 464.0, -100, -100.0, 469.5, 457.4, 457.5]) * 2 * np.pi
# detuning_1256 = detuning_1234
# detuning_1267 = np.array([500, 500, -287.3, -141.7, -243.8, 450, 450.0, -265.4]) * 2 * np.pi
# detuning_1278 = detuning_1234

# # 23-xy
# detuning_2345 = np.array([-255.4, 500, 500, -15, -15, 397.3, 399.7, -270.7]) * 2 * np.pi
# detuning_2356 = np.array([-238.7, 450, 450, -338.0, 10, 10, -321.2, -270.7]) * 2 * np.pi
# detuning_2367 = detuning_2345
# detuning_2378 = np.array([-229.5, 580, 580.0, -124.5, -236.3, -131.8, 375, 375.0]) * 2 * np.pi

# # 34-xy
# detuning_3456 = detuning_1234
# detuning_3467 = np.array([-255.4, -252.4, 580, 580.0, -253.6, 200, 200.0, -270.7]) * 2 * np.pi
# detuning_3478 = detuning_1234

# # 45-xy
# detuning_4567 = detuning_2345
# detuning_4578 = np.array([-255.4, 627.7, 592.8, 100, 100.0, 599.4, -200, -200.0]) * 2 * np.pi

# # 56-78
# detuning_5678 = detuning_1234


# configuration_to_date_code_highest['12-34-56-78'] = ('2026', '01', '10', '00', '24', '23') # high quality 1234
# configuration_to_date_code_disordered['12-34-56-78'] = ('2026', '01', '10', '02', '04', '27') # high quality 1234

# configuration_to_date_code_highest['1-23-45-67-8'] = ('2026', '01', '12', '07', '58', '19') # high quality 2345
# configuration_to_date_code_disordered['1-23-45-67-8'] = ('2026', '01', '12', '07', '49', '53') # high quality 2345


# configuration_to_date_code_highest['12-3-45-6-7-8'] = ('2025', '12', '11', '15', '16', '06') # high quality 1245
# configuration_to_date_code_disordered['12-3-45-6-7-8'] = ('2025', '12', '11', '15', '48', '57') # high quality 1245

# configuration_to_date_code_highest['12-3-4-5-67-8'] = ('2026', '01', '07', '17', '03', '16') # high quality 1267
# configuration_to_date_code_disordered['12-3-4-5-67-8'] = ('2026', '01', '07', '16', '24', '33') # high quality 1267

# configuration_to_date_code_highest['1-23-4-56-7-8'] = ('2026', '01', '06', '01', '27', '12') # high quality 2356
# configuration_to_date_code_disordered['1-23-4-56-7-8'] = ('2026', '01', '05', '23', '36', '22') # high quality 2356

# configuration_to_date_code_highest['1-23-4-5-6-78'] = ('2025', '12', '16', '00', '24', '35') # high quality 2378
# configuration_to_date_code_disordered['1-23-4-5-6-78'] = ('2025', '12', '16', '01', '59', '28') # high quality 2378

# configuration_to_date_code_highest['1-2-34-5-67-8'] = ('2025', '12', '12', '07', '01', '44') # high quality 3467
# configuration_to_date_code_disordered['1-2-34-5-67-8'] = ('2025', '12', '12', '07', '34', '33') # high quality 3467

# configuration_to_date_code_highest['1-2-3-45-6-78'] = ('2025', '12', '12', '18', '14', '53') # high quality 4578
# configuration_to_date_code_disordered['1-2-3-45-6-78'] = ('2025', '12', '12', '18', '47', '38') # high quality 4578


#######################################################################
#######################################################################


# coupling point 4
# 0 flux, ratio=1

# J_dict['J_13'] = 6.21
# J_dict['J_24'] = 6.08
# J_dict['J_35'] = 6.10
# J_dict['J_46'] = 6.32
# J_dict['J_57'] = 6.24
# J_dict['J_68'] = 6.61

# J_dict['J_12'] = -6.21
# J_dict['J_23'] = -6.57
# J_dict['J_34'] = -6.38
# J_dict['J_45'] = -6.56
# J_dict['J_56'] = -6.36
# J_dict['J_67'] = -6.53
# J_dict['J_78'] = -6.30

# T2_dict['T2_1'] = 2.186
# T2_dict['T2_2'] = 0.740
# T2_dict['T2_3'] = 2.597
# T2_dict['T2_4'] = 1.485
# T2_dict['T2_5'] = 2.077
# T2_dict['T2_6'] = 2.522
# T2_dict['T2_7'] = 2.330
# T2_dict['T2_8'] = 1.934

# # 12-xy
# detuning_1234 = np.array([-200, -200, 500, 500, -100, -100, 300, 300]) * 2 * np.pi # MHz
# detuning_1245 = np.array([500, 500, -300, 100, 100, -300, -300, -300]) * 2 * np.pi
# detuning_1256 = detuning_1234
# detuning_1267 = np.array([550, 550, -300, -300, -300, 450, 450, -300]) * 2 * np.pi
# detuning_1278 = detuning_1234

# # 23-xy
# detuning_2345 = np.array([-300, 450, 450, -200, -200, 350, 350, -300]) * 2 * np.pi # MHz
# detuning_2356 = np.array([-300, 100, 100, -300, 500, 500, -300, -300]) * 2 * np.pi
# detuning_2367 = detuning_2345
# detuning_2378 = np.array([-300, 550, 550, -300, -300, -300, 450, 450]) * 2 * np.pi

# # 34-xy
# detuning_3456 = detuning_1234
# detuning_3467 = np.array([-300, -300, 100, 100, -300, 500, 500, -300]) * 2 * np.pi
# detuning_3478 = detuning_1234

# # 45-xy
# detuning_4567 = detuning_2345
# detuning_4578 = np.array([-300, -300, -300, 100, 100, -300, 500, 500]) * 2 * np.pi

# # 56-78
# detuning_5678 = detuning_1234

# configuration_to_date_code_highest['12-34-56-78'] = ('2025', '11', '14', '20', '59', '07')
# configuration_to_date_code_lowest['12-34-56-78'] = ('2025', '11', '14', '21', '39', '41')

# configuration_to_date_code_highest['1-23-45-67-8'] = ('2025', '11', '15', '00', '21', '31')
# configuration_to_date_code_lowest['1-23-45-67-8'] = ('2025', '11', '15', '01', '10', '25')


# configuration_to_date_code_highest['12-3-45-6-7-8'] = ('2025', '11', '15', '11', '58', '35')
# configuration_to_date_code_lowest['12-3-45-6-7-8'] = ('2025', '11', '15', '15', '07', '34')


# configuration_to_date_code_highest['12-3-4-5-67-8'] = ('2025', '11', '15', '21', '36', '50')
# configuration_to_date_code_lowest['12-3-4-5-67-8'] = ('2025', '11', '15', '23', '06', '51')

# configuration_to_date_code_highest['1-23-4-56-7-8'] = ('2025', '11', '16', '20', '21', '14')
# configuration_to_date_code_lowest['1-23-4-56-7-8'] = ('2025', '11', '16', '22', '32', '09')


# configuration_to_date_code_highest['1-23-4-5-6-78'] = ('2025', '11', '17', '14', '18', '58')
# configuration_to_date_code_lowest['1-23-4-5-6-78'] = ('2025', '11', '17', '11', '17', '43')


# configuration_to_date_code_highest['1-2-34-5-67-8'] = ('2025', '11', '17', '16', '21', '25')
# configuration_to_date_code_lowest['1-2-34-5-67-8'] = ('2025', '11', '17', '17', '14', '14')


# configuration_to_date_code_highest['1-2-3-45-6-78'] = ('2025', '11', '17', '19', '25', '09')
# configuration_to_date_code_lowest['1-2-3-45-6-78'] = ('2025', '11', '17', '20', '44', '36')



#######################################################################
#######################################################################


# coupling point 5
# 0 flux, ratio=2


# J_dict = {}

# J_dict['J_13'] = 13.41
# J_dict['J_24'] = 13.59
# J_dict['J_35'] = 12.67
# J_dict['J_46'] = 12.94
# J_dict['J_57'] = 12.67
# J_dict['J_68'] = 12.60

# J_dict['J_12'] = -6.30
# J_dict['J_23'] = -6.78
# J_dict['J_34'] = -6.69
# J_dict['J_45'] = -6.78
# J_dict['J_56'] = -6.59
# J_dict['J_67'] = -6.74
# J_dict['J_78'] = -6.39

# J_error_dict = {}

# J_error_dict['J_13'] = 0.03
# J_error_dict['J_24'] = 0.04
# J_error_dict['J_35'] = 0.03
# J_error_dict['J_46'] = 0.04
# J_error_dict['J_57'] = 0.03
# J_error_dict['J_68'] = 0.05

# J_error_dict['J_12'] = 0.04
# J_error_dict['J_23'] = 0.04
# J_error_dict['J_34'] = 0.06
# J_error_dict['J_45'] = 0.01
# J_error_dict['J_56'] = 0.04
# J_error_dict['J_67'] = 0.01
# J_error_dict['J_78'] = 0.01


# T2_dict['T2_1'] = 1.889
# T2_dict['T2_2'] = 1.049
# T2_dict['T2_3'] = 3.371
# T2_dict['T2_4'] = 0.555
# T2_dict['T2_5'] = 3.472
# T2_dict['T2_6'] = 1.
# T2_dict['T2_7'] = 1.604
# T2_dict['T2_8'] = 1.599

# # 12-xy
# detuning_1234 = np.array([-200., -200., 400., 400., -100., -100., 300., 300.]) * 2 * np.pi  # MHz
# detuning_1245 = np.array([100., 100., 350., -200., -200., 346.5, 347., 370.7]) * 2 * np.pi
# detuning_1256 = detuning_1234
# detuning_1267 = np.array([200., 200., -347.3, -303.9, -309.6, 300., 300., -300.1]) * 2 * np.pi
# detuning_1278 = detuning_1234

# # 23-xy
# detuning_2345 = np.array([-288.1, 200., 200., -150., -150., 305.3, 300., -300.1]) * 2 * np.pi  # MHz
# detuning_2356 = np.array([-288.1, 300., 300., -303.9, 0., 0., -363.1, -300.1]) * 2 * np.pi
# detuning_2367 = detuning_2345
# detuning_2378 = np.array([-288.1, 300., 300., -303.9, -309.6, -308.1, -25., -25.]) * 2 * np.pi

# # 34-xy
# detuning_3456 = detuning_1234
# detuning_3467 = np.array([-288.1, -296., 300., 300., -309.6, 0., 0., -300.1]) * 2 * np.pi
# detuning_3478 = detuning_1234

# # 45-xy
# detuning_4567 = detuning_2345

# configuration_to_date_code_highest['12-34-56-78'] = ('2026', '01', '22', '18', '42', '05') # high quality 1234
# configuration_to_date_code_disordered['12-34-56-78'] = ('2026', '01', '22', '17', '43', '40') # high quality 1234

# configuration_to_date_code_highest['1-23-45-67-8'] = ('2026', '01', '23', '03', '31', '33') # high quality 2345
# configuration_to_date_code_disordered['1-23-45-67-8'] = ('2026', '01', '23', '02', '33', '59') # high quality 2345


# configuration_to_date_code_highest['12-3-45-6-7-8'] = ('2026', '01', '21', '19', '05', '24') # high quality 1245
# configuration_to_date_code_disordered['12-3-45-6-7-8'] = ('2026', '01', '20', '15', '49', '00') # high quality 1245

# configuration_to_date_code_highest['12-3-4-5-67-8'] = ('2026', '01', '23', '01', '36', '23') # high quality 1267
# configuration_to_date_code_disordered['12-3-4-5-67-8'] = ('2026', '01', '23', '00', '38', '22') # high quality 1267

# configuration_to_date_code_highest['1-23-4-56-7-8'] = ('2026', '01', '23', '05', '26', '34') # high quality 2356
# configuration_to_date_code_disordered['1-23-4-56-7-8'] = ('2026', '01', '23', '04', '29', '02') # high quality 2356

# configuration_to_date_code_highest['1-23-4-5-6-78'] = ('2026', '01', '23', '10', '53', '39') # high quality 2378
# configuration_to_date_code_disordered['1-23-4-5-6-78'] = ('2026', '01', '23', '06', '24', '09') # high quality 2378

# configuration_to_date_code_highest['1-2-34-5-67-8'] = ('2026', '01', '24', '17', '05', '54') # high quality 3467
# configuration_to_date_code_disordered['1-2-34-5-67-8'] = ('2026', '01', '24', '16', '36', '27') # high quality 3467

# configuration_to_date_code_highest['1-2-3-45-6-78'] = ('2026', '01', '23', '19', '19', '28') # high quality 4578
# configuration_to_date_code_disordered['1-2-3-45-6-78'] = ('2026', '01', '23', '18', '21', '47') # high quality 4578

# %%
# ### add h5py filenames of measurement files


# configuration_to_date_code_highest = {}
# configuration_to_date_code_lowest = {}
# configuration_to_date_code_disordered = {}

# eigenstate_dict = {'highest': configuration_to_date_code_highest,
#                    'lowest': configuration_to_date_code_lowest,
#                    'disordered': configuration_to_date_code_disordered}



# configuration_to_date_code_highest['12-34-56-78'] = ('2026', '01', '22', '18', '42', '05') # high quality 1234
# configuration_to_date_code_disordered['12-34-56-78'] = ('2026', '01', '22', '17', '43', '40') # high quality 1234

# configuration_to_date_code_highest['1-23-45-67-8'] = ('2026', '01', '23', '03', '31', '33') # high quality 2345
# configuration_to_date_code_disordered['1-23-45-67-8'] = ('2026', '01', '23', '02', '33', '59') # high quality 2345


# configuration_to_date_code_highest['12-3-45-6-7-8'] = ('2026', '01', '21', '19', '05', '24') # high quality 1245
# configuration_to_date_code_disordered['12-3-45-6-7-8'] = ('2026', '01', '20', '15', '49', '00') # high quality 1245

# configuration_to_date_code_highest['12-3-4-5-67-8'] = ('2026', '01', '23', '01', '36', '23') # high quality 1267
# configuration_to_date_code_disordered['12-3-4-5-67-8'] = ('2026', '01', '23', '00', '38', '22') # high quality 1267

# configuration_to_date_code_highest['1-23-4-56-7-8'] = ('2026', '01', '23', '05', '26', '34') # high quality 2356
# configuration_to_date_code_disordered['1-23-4-56-7-8'] = ('2026', '01', '23', '04', '29', '02') # high quality 2356

# configuration_to_date_code_highest['1-23-4-5-6-78'] = ('2026', '01', '23', '10', '53', '39') # high quality 2378
# configuration_to_date_code_disordered['1-23-4-5-6-78'] = ('2026', '01', '23', '06', '24', '09') # high quality 2378

# configuration_to_date_code_highest['1-2-34-5-67-8'] = ('2026', '01', '24', '17', '05', '54') # high quality 3467
# configuration_to_date_code_disordered['1-2-34-5-67-8'] = ('2026', '01', '24', '16', '36', '27') # high quality 3467

# configuration_to_date_code_highest['1-2-3-45-6-78'] = ('2026', '01', '23', '19', '19', '28') # high quality 4578
# configuration_to_date_code_disordered['1-2-3-45-6-78'] = ('2026', '01', '23', '18', '21', '47') # high quality 4578


# keys = (coupling_point, 'data_config')


# # backup_config(config_filename)
# for eigenstate in eigenstate_dict:
#     for correlation_pair in correlation_pair_to_configuration:
        
#         configuration = correlation_pair_to_configuration[correlation_pair]


#         if not configuration in eigenstate_dict[eigenstate]:
#             continue

#         date_code = eigenstate_dict[eigenstate][configuration]

#         date_code_dict = {}
#         date_code_dict['year'] = str(date_code[0])
#         date_code_dict['month'] = str(date_code[1])
#         date_code_dict['day'] = str(date_code[2])
#         date_code_dict['hour'] = str(date_code[3])
#         date_code_dict['minute'] = str(date_code[4])
#         date_code_dict['second'] = str(date_code[5])


#         update_config(config_filename, date_code_dict, keys + (str(correlation_pair), eigenstate), save_backup=False)

# %%
### add filename base for each measurement

filename_base = None
# filename_base = 'RampBeamsplitterCorrelationsR'
# filename_base = 'RampBeamsplitterCleanTiming'
# filename_base = 'RampDoubleJumpCurrentCorrelations'
filename_base = 'BSClean_Correlations'

keys = (coupling_point, 'data_config')
# eigenstate = 'highest'
eigenstate = 'disordered'

correlation_pairs_to_update = []

for i in range(1,8):
    for j in range(i+2,8):
        correlation_pair = ((i,i+1),(j,j+1))
        correlation_pairs_to_update.append(correlation_pair)

# correlation_pairs_to_update = [((1,2),(3,4)),
#                                ((2,3),(4,5)),
#                                ((3,4),(5,6)),
#                                ((4,5),(6,7)),
#                                ((5,6),(7,8)),
#                                ((1,2),(5,6)),
#                                ((2,3),(6,7)),
#                                ((3,4),(7,8)),
#                                ((1,2),(7,8)),]

backup_config(config_filename)
for correlation_pair in correlation_pairs_to_update:
    update_config(config_filename, filename_base, keys + (str(correlation_pair), eigenstate, 'filename_base'), save_backup=False)

# %%
### add beamsplitter times (in ns) for each correlation pair

correlation_pair_to_beamsplitter_time = {}

beamsplitter_time_default = 25


correlation_pair_to_beamsplitter_time[((1,2),(3,4))] = beamsplitter_time_default
correlation_pair_to_beamsplitter_time[((1,2),(4,5))] = beamsplitter_time_default 
correlation_pair_to_beamsplitter_time[((1,2),(5,6))] = beamsplitter_time_default 
correlation_pair_to_beamsplitter_time[((1,2),(6,7))] = beamsplitter_time_default
correlation_pair_to_beamsplitter_time[((1,2),(7,8))] = beamsplitter_time_default 

correlation_pair_to_beamsplitter_time[((2,3),(4,5))] = beamsplitter_time_default
correlation_pair_to_beamsplitter_time[((2,3),(5,6))] = beamsplitter_time_default
correlation_pair_to_beamsplitter_time[((2,3),(6,7))] = beamsplitter_time_default
correlation_pair_to_beamsplitter_time[((2,3),(7,8))] = beamsplitter_time_default 

correlation_pair_to_beamsplitter_time[((3,4),(5,6))] = beamsplitter_time_default
correlation_pair_to_beamsplitter_time[((3,4),(6,7))] = beamsplitter_time_default
correlation_pair_to_beamsplitter_time[((3,4),(7,8))] = beamsplitter_time_default 

correlation_pair_to_beamsplitter_time[((4,5),(6,7))] = beamsplitter_time_default 
correlation_pair_to_beamsplitter_time[((4,5),(7,8))] = beamsplitter_time_default

correlation_pair_to_beamsplitter_time[((5,6),(7,8))] = beamsplitter_time_default 


keys = (coupling_point, 'data_config')


backup_config(config_filename)
for correlation_pair in correlation_pair_to_beamsplitter_time:
    correlation_pair_key = str(correlation_pair)
    print(correlation_pair_key)
    beamsplitter_time = correlation_pair_to_beamsplitter_time[correlation_pair]
    update_config(config_filename, beamsplitter_time, keys + (correlation_pair_key, 'beamsplitter_time'), save_backup=False)
# Out:
# ((1, 2), (3, 4))
# ((1, 2), (4, 5))
# ((1, 2), (5, 6))
# ((1, 2), (6, 7))
# ((1, 2), (7, 8))
# ((2, 3), (4, 5))
# ((2, 3), (5, 6))
# ((2, 3), (6, 7))
# ((2, 3), (7, 8))
# ((3, 4), (5, 6))
# ((3, 4), (6, 7))
# ((3, 4), (7, 8))
# ((4, 5), (6, 7))
# ((4, 5), (7, 8))
# ((5, 6), (7, 8))

# %% [markdown]
# # 2. Simulation Parameters

# %%
simulation_config_dict = {
    'num_levels': 5,
    'num_qubits': 8,
    'num_particles': 4,
    'U': -180,
    'psi0': -1,
    'T1': 40,
    'T2': 2,
    'time_start': 0,
    'time_stop': 0.16,
    'time_num_points': 201,
    'ramp_time': 0.290
    
}


keys = (coupling_point, 'simulation_config',)
update_config(config_filename, simulation_config_dict, keys, save_backup=True)

# %% [markdown]
# # 3. Edits

# %% [markdown]
# ### 3.1 Delete

# %%
# ### CAREFUL!! ### 
# # only run to remove certain sections of the json file

# backup_config(config_filename)
# labels = ['year', 'month', 'day', 'hour', 'minute', 'second']
# for correlation_pair in correlation_pair_to_configuration:
#     for label in labels:
#         keys = ('coupling_point_2', 'data_config', str(correlation_pair), label)

#         remove_field(config_filename, keys)

# %%
# ### CAREFUL!! ### 
# # only run to remove certain sections of the json file

# backup_config(config_filename)
# for correlation_pair in correlation_pair_to_configuration:
#     keys = ('coupling_point_4', 'data_config', str(correlation_pair), 'disordered')

#     remove_field(config_filename, keys)
