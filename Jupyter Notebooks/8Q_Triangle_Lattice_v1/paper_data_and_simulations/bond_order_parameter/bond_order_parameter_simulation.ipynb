# %%
import matplotlib.pyplot as plt
import numpy as np
import qutip as qt

import csv
import h5py
import json
from datetime import datetime
import sys
import os
import shutil
import importlib
from itertools import product

sys.path.append(r"C:\Users\mattm\OneDrive\Desktop\Research\Projects\Triangle Lattice\Jupyter Notebooks\8Q_Triangle_Lattice_v1")
sys.path.append(r"C:\Users\mattm\OneDrive\Desktop\Research\Projects\Triangle Lattice\Jupyter Notebooks\8Q_Triangle_Lattice_v1\current_measurements")
sys.path.append(r"C:\Users\mattm\OneDrive\Desktop\Research\Projects\Triangle Lattice\Jupyter Notebooks\8Q_Triangle_Lattice_v1\current_simulations")
sys.path.append(r"C:\Users\mattm\OneDrive\Desktop\Research\Projects\Triangle Lattice\Jupyter Notebooks\8Q_Triangle_Lattice_v1\paper_data_and_simulations\ramp_dephasing_simulations")

sys.path.append(r"E:\Research\Projects\Triangle Lattice\chiral_currents_project\Jupyter Notebooks\8Q_Triangle_Lattice_v1")
sys.path.append(r"E:\Research\Projects\Triangle Lattice\chiral_currents_project\Jupyter Notebooks\8Q_Triangle_Lattice_v1\current_measurements")
sys.path.append(r"E:\Research\Projects\Triangle Lattice\chiral_currents_project\Jupyter Notebooks\8Q_Triangle_Lattice_v1\current_simulations")
sys.path.append(r"E:\Research\Projects\Triangle Lattice\chiral_currents_project\Jupyter Notebooks\8Q_Triangle_Lattice_v1\paper_data_and_simulations\ramp_dephasing_simulations")
sys.path.append(r"E:\Research\Projects\Triangle Lattice\chiral_currents_project\Jupyter Notebooks\8Q_Triangle_Lattice_v1\paper_data_and_simulations\ramp_dephasing_simulations")


import current_measurements.src.src_current_measurement_simulations_particle_sector
importlib.reload(current_measurements.src.src_current_measurement_simulations_particle_sector);
from current_measurements.src.src_current_measurement_simulations_particle_sector import CurrentMeasurementSimulationParticleSector

import current_simulations.quantum_states
importlib.reload(current_simulations.quantum_states)
from current_simulations.quantum_states import QuantumState, FockBasisState, FockBasisOuter, DensityMatrix

import quantum_states
importlib.reload(quantum_states)
from quantum_states import QuantumState, FockBasisState, FockBasisOuter, DensityMatrix

import current_simulations.current_simulation
importlib.reload(current_simulations.current_simulation)
from current_simulations.current_simulation import CurrentSimulation


import qt_qubit_sys
importlib.reload(qt_qubit_sys)
from qt_qubit_sys import *

# %% [markdown]
# # 1. No Dephasing

# %% [markdown]
# ### 1.1 Helpers

# %%
def convert_particle_sector_to_reduced_density_matrix(psi_4particle, 
                                                      basis_4particle, 
                                                      reduced_qubit_indices, 
                                                      num_qubits=8,
                                                      num_levels=5):
    """
    More efficient version that groups states by their traced configurations
    Handles both state vectors and density matrices as input.

    after reducing to reduced density matrix, truncate to remove states that have more than 4 particles in total
    """
    from collections import defaultdict
    
    # Check if input is a density matrix or state vector
    if hasattr(psi_4particle, 'shape') and len(psi_4particle.shape) == 2:
        # Input is a density matrix
        is_density_matrix = True
        if hasattr(psi_4particle, 'full'):
            rho_input = psi_4particle.full()  # QuTiP Qobj
        else:
            rho_input = psi_4particle  # numpy array
    else:
        # Input is a state vector
        is_density_matrix = False
        if hasattr(psi_4particle, 'full'):
            psi_input = psi_4particle.full().flatten()  # QuTiP Qobj
        else:
            psi_input = psi_4particle.flatten()  # numpy array
    

    if psi_4particle.isket:
        is_density_matrix = False
        psi_input = psi_4particle.full().flatten()

    elif psi_4particle.isoper:
        is_density_matrix = True
        rho_input = psi_4particle.full()



    traced_qubits = [i for i in range(num_qubits) if i not in reduced_qubit_indices]
    
    # Group states by (reduced_config, traced_config)
    state_groups = defaultdict(list)
    
    for i, full_state in enumerate(basis_4particle):
        reduced_part = tuple(full_state[j] for j in reduced_qubit_indices)
        traced_part = tuple(full_state[j] for j in traced_qubits)
        state_groups[(reduced_part, traced_part)].append(i)
    
    # Generate basis for reduced qubits
    reduced_basis = list(product(range(num_levels), repeat=len(reduced_qubit_indices)))
    dim_reduced = len(reduced_basis)
    rho_reduced = np.zeros((dim_reduced, dim_reduced), dtype=complex)
    
    # Build density matrix
    for alpha, reduced_alpha in enumerate(reduced_basis):
        for beta, reduced_beta in enumerate(reduced_basis):
            
            matrix_element = 0.0
            
            # Sum over all traced configurations
            all_traced_configs = set()
            for (red_part, traced_part), indices in state_groups.items():
                if red_part == reduced_alpha or red_part == reduced_beta:
                    all_traced_configs.add(traced_part)
            
            for traced_config in all_traced_configs:
                indices_alpha = state_groups.get((reduced_alpha, traced_config), [])
                indices_beta = state_groups.get((reduced_beta, traced_config), [])
                
                if is_density_matrix:
                    # For density matrix input: Tr_traced[rho] = sum over traced indices
                    for i in indices_alpha:
                        for j in indices_beta:
                            matrix_element += rho_input[i, j]
                else:
                    # For state vector input: |psi><psi| -> sum coefficients
                    coeff_alpha = sum(psi_input[i] for i in indices_alpha)
                    coeff_beta = sum(psi_input[i] for i in indices_beta)
                    matrix_element += coeff_alpha * np.conj(coeff_beta)

            rho_reduced[alpha, beta] = matrix_element

    
    basis_4Q_reduced_indices = np.where([sum(state) <= 4 for state in reduced_basis])[0]
    rho_reduced = rho_reduced[basis_4Q_reduced_indices,:][:,basis_4Q_reduced_indices]
    
    return qt.Qobj(rho_reduced, dims=[[len(basis_4Q_reduced_indices)], [len(basis_4Q_reduced_indices)]])

# %%
def backup_data(data_filename):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename_only = os.path.basename(data_filename)
    name, ext = os.path.splitext(filename_only)
    backup_name = f"{name}_{timestamp}{ext}"
    backup_path = os.path.join('data_backups', backup_name)
    shutil.copy2(data_filename, backup_path)

def save_nested_dict_to_hdf5(filename, data, save_backup=True):

    if save_backup:
        backup_data(filename)

    with h5py.File(filename, 'w') as f:
        def _save_dict(group, dictionary):
            for key, value in dictionary.items():
                if isinstance(value, dict):
                    subgroup = group.create_group(str(key))
                    _save_dict(subgroup, value)
                elif isinstance(value, np.ndarray):
                    group.create_dataset(key, data=value, compression='gzip')
                elif isinstance(value, list):
                    group.create_dataset(key, data=np.array(value), compression='gzip')
                else:
                    group.attrs[key] = value  # Store scalars as attributes
        
        _save_dict(f, data)

def update_data_file(filename, data, keys, save_backup=True):
    if save_backup:
        backup_data(filename)
    
    with h5py.File(filename, 'a') as f:  # Open in append mode
        def _navigate_to_parent(group, key_path):
            """Navigate to the parent group of the target location"""
            current_group = group
            for key in key_path[:-1]:  # All keys except the last one
                if str(key) in current_group:
                    current_group = current_group[str(key)]
                else:
                    # Create the group if it doesn't exist
                    current_group = current_group.create_group(str(key))
            return current_group
        
        def _save_data_at_location(group, key, value):
            """Save data at a specific location, replacing if it exists"""
            # Remove existing data if it exists
            if key in group:
                del group[key]
            
            # Save new data
            if isinstance(value, dict):
                subgroup = group.create_group(key)
                _save_dict(subgroup, value)
            elif isinstance(value, np.ndarray):
                group.create_dataset(key, data=value, compression='gzip')
            elif isinstance(value, list):
                group.create_dataset(key, data=np.array(value), compression='gzip')
            else:
                group.attrs[key] = value  # Store scalars as attributes
        
        def _save_dict(group, dictionary):
            """Helper function to save nested dictionaries"""
            for key, value in dictionary.items():
                _save_data_at_location(group, str(key), value)
        
        # Navigate to the parent location
        parent_group = _navigate_to_parent(f, keys)
        
        # Save the data at the final key location
        final_key = str(keys[-1])
        _save_data_at_location(parent_group, final_key, data)


def load_nested_dict_from_hdf5(filename):
    def _load_dict(group):
        result = {}
        for key in group.keys():
            if isinstance(group[key], h5py.Group):
                result[key] = _load_dict(group[key])
            else:
                result[key] = group[key][()]  # Load dataset
        
        # Load attributes (scalars)
        for key, value in group.attrs.items():
            result[key] = value
            
        return result
    
    with h5py.File(filename, 'r') as f:
        return _load_dict(f)


def print_tree(data, max_level=None):
    def __print_tree_recursive(root, level=0):
        if isinstance(root, dict):
            if not max_level is None and level == max_level:
                return
            level_str = '- '*level
            for key in root:
                print(f'{level_str}{key}')
                __print_tree_recursive(root[key], level+1)
    __print_tree_recursive(data)

# %% [markdown]
# ### 1.2 Sweep $J/J_{||}$

# %%
### initialize parameters

J = -5.5 * 2 * np.pi # 2pi MHz
U = -180 * 2 * np.pi # 2pi MHz

# testing different Us
# U = 0

T1 = None
T2 = None

psi0 = -1
times = np.linspace(0, 0.15, 11)


ratios = np.linspace(-3.6, 3, 101)

J_parallel_sweep = np.abs(J) * ratios

# %%
num_levels = 5
num_qubits = 8
num_particles = 4

basis = list(product(range(num_levels), repeat=num_qubits))
basis_4Q = [state for state in basis if sum(state) == num_particles]


pairs = [(i,i+1) for i in range(1,num_qubits)]

# %%
bond_order_parameters = []


for i in range(len(J_parallel_sweep)):

    J_parallel = J_parallel_sweep[i]

    # create initial state from diagonalizing the particle sector Hamiltonian

    simulation = CurrentMeasurementSimulationParticleSector(num_levels, num_qubits, num_particles, J, J_parallel, U, times,
                                                        [1,2], [3,4], psi0=psi0, T1=T1, T2=T2)

    # print(f'num_levels: {num_levels}')
    # print(f'num_qubits: {num_qubits}')
    # print(f'J_parallel: {J_parallel}')
    # print(f'J: {J}')
    # print(f'U: {U}')
    # print(f'psi0: {psi0}')


    psi0_state = simulation.psi0




    # create fock state out of psi0

    basis_4Q_fock = [FockBasisState(state) for state in basis_4Q]

    # basis_fock = [FockBasisState(state) for state in basis]

    assert psi0_state.isket
    psi0_fock = QuantumState(psi0_state.full()[:,0], basis_4Q_fock)

    bond_order_value_from_operator = {}

    for pair in pairs:
        value = None
        if isinstance(psi0_fock, QuantumState):
            new_state = psi0_fock.apply_raising_operator(pair[0]-1, num_levels).apply_lowering_operator(pair[1]-1)
            value = psi0_fock.inner_product(new_state)
        elif isinstance(psi0_fock, DensityMatrix):
            new_state = psi0_fock.apply_raising_operator_left(pair[0]-1, num_levels).apply_lowering_operator_left(pair[1]-1)
            value = new_state.trace()
        bond_order_value_from_operator[pair] = 2*value.real


    bond_order_values = np.zeros(len(pairs))

    for j in range(len(pairs)):
        bond_order_values[j] = bond_order_value_from_operator[pairs[j]]


    bond_order_total_operator = 0
    for j in range(len(bond_order_values)):
        bond_order_total_operator += bond_order_values[j] * (-1)**j  # alternating sign    
    print(f"ratio = {ratios[i]}")
    print(bond_order_values)

    data_dictionary = {}


    for pair in pairs:

        data_dictionary[pair] = {}

        data_dictionary[pair]['bond_order_value'] = bond_order_value_from_operator[pair]

    data_dictionary['bond_order_total'] = bond_order_total_operator

    bond_order_value_operators = np.array([bond_order_value_from_operator[pair] for pair in pairs])

    bond_order_total_operator = 0
    for pair in pairs:
        bond_order_total_operator += bond_order_value_from_operator[pair] * (-1)**(pair[0])  # alternating sign    

    bond_order_parameters.append(bond_order_total_operator)

    print(f"bond order total operator: {bond_order_total_operator}")
# Out:
# processing psi0, given type: <class 'int'>
# ratio = -3.6
# [-0.23364715  0.19178918 -0.22742868  0.12205814 -0.22742868  0.19178918
#  -0.23364715]
# bond order total operator: 1.427788163076283
# processing psi0, given type: <class 'int'>
# ratio = -3.5340000000000003
# [-0.23663887  0.19383957 -0.22948068  0.12233565 -0.22948068  0.19383957
#  -0.23663887]
# bond order total operator: 1.4422538982752213
# processing psi0, given type: <class 'int'>
# ratio = -3.468
# [-0.23973695  0.19595874 -0.23160785  0.12263073 -0.23160785  0.19595874
#  -0.23973695]
# bond order total operator: 1.4572378030085376
# processing psi0, given type: <class 'int'>
# ratio = -3.402
# [-0.24294834  0.19815077 -0.23381527  0.12294529 -0.23381527  0.19815077
#  -0.24294834]
# bond order total operator: 1.4727740403523244
# processing psi0, given type: <class 'int'>
# ratio = -3.3360000000000003
# [-0.24628065  0.20042003 -0.23610847  0.12328144 -0.23610847  0.20042003
#  -0.24628065]
# bond order total operator: 1.4888997430330393
# processing psi0, given type: <class 'int'>
# ratio = -3.27
# [-0.24974217  0.20277127 -0.23849349  0.12364148 -0.23849349  0.20277127
#  -0.24974217]
# bond order total operator: 1.505655335653416
# processing psi0, given type: <class 'int'>
# ratio = -3.204
# [-0.253342    0.20520955 -0.24097692  0.12402796 -0.24097692  0.20520955
#  -0.253342  ]
# bond order total operator: 1.523084899242328
# processing psi0, given type: <class 'int'>
# ratio = -3.138
# [-0.25709011  0.20774037 -0.24356596  0.1244437  -0.24356596  0.20774037
#  -0.25709011]
# bond order total operator: 1.5412365846035583
# processing psi0, given type: <class 'int'>
# ratio = -3.072
# [-0.26099747  0.21036963 -0.24626852  0.12489183 -0.24626852  0.21036963
#  -0.26099747]
# bond order total operator: 1.5601630820441907
# processing psi0, given type: <class 'int'>
# ratio = -3.0060000000000002
# [-0.26507618  0.21310372 -0.24909328  0.1253758  -0.24909328  0.21310372
#  -0.26507618]
# bond order total operator: 1.579922156375053
# processing psi0, given type: <class 'int'>
# ratio = -2.94
# [-0.26933959  0.21594953 -0.25204978  0.12589946 -0.25204978  0.21594953
#  -0.26933959]
# bond order total operator: 1.6005772576228052
# processing psi0, given type: <class 'int'>
# ratio = -2.874
# [-0.27380249  0.21891451 -0.25514855  0.1264671  -0.25514855  0.21891451
#  -0.27380249]
# bond order total operator: 1.6221982197208344
# processing psi0, given type: <class 'int'>
# ratio = -2.808
# [-0.27848132  0.22200671 -0.25840126  0.12708349 -0.25840126  0.22200671
#  -0.27848132]
# bond order total operator: 1.6448620615979874
# processing psi0, given type: <class 'int'>
# ratio = -2.742
# [-0.28339437  0.2252348  -0.26182079  0.12775398 -0.26182079  0.2252348
#  -0.28339437]
# bond order total operator: 1.6686539076048454
# processing psi0, given type: <class 'int'>
# ratio = -2.676
# [-0.28856204  0.2286082  -0.26542151  0.12848456 -0.26542151  0.2286082
#  -0.28856204]
# bond order total operator: 1.6936680471573742
# processing psi0, given type: <class 'int'>
# ratio = -2.6100000000000003
# [-0.29400719  0.23213702 -0.26921938  0.12928197 -0.26921938  0.23213702
#  -0.29400719]
# bond order total operator: 1.720009156865015
# processing psi0, given type: <class 'int'>
# ratio = -2.544
# [-0.2997555   0.23583219 -0.27323226  0.1301538  -0.27323226  0.23583219
#  -0.2997555 ]
# bond order total operator: 1.7477937122656586
# processing psi0, given type: <class 'int'>
# ratio = -2.4779999999999998
# [-0.30583587  0.23970548 -0.27748015  0.13110862 -0.27748015  0.23970548
#  -0.30583587]
# bond order total operator: 1.777151620570173
# processing psi0, given type: <class 'int'>
# ratio = -2.412
# [-0.312281    0.24376948 -0.28198551  0.13215613 -0.28198551  0.24376948
#  -0.312281  ]
# bond order total operator: 1.8082281104086555
# processing psi0, given type: <class 'int'>
# ratio = -2.346
# [-0.31912792  0.24803766 -0.28677369  0.13330738 -0.28677369  0.24803766
#  -0.31912792]
# bond order total operator: 1.8411859191841735
# processing psi0, given type: <class 'int'>
# ratio = -2.2800000000000002
# [-0.32641881  0.25252433 -0.29187332  0.13457491 -0.29187332  0.25252433
#  -0.32641881]
# bond order total operator: 1.8762078227311012
# processing psi0, given type: <class 'int'>
# ratio = -2.214
# [-0.3342018   0.25724453 -0.29731691  0.13597308 -0.29731691  0.25724453
#  -0.3342018 ]
# bond order total operator: 1.9134995545249756
# processing psi0, given type: <class 'int'>
# ratio = -2.148
# [-0.34253209  0.2622139  -0.30314145  0.13751829 -0.30314145  0.2622139
#  -0.34253209]
# bond order total operator: 1.9532931609082018
# processing psi0, given type: <class 'int'>
# ratio = -2.082
# [-0.3514731   0.26744841 -0.3093892   0.13922941 -0.3093892   0.26744841
#  -0.3514731 ]
# bond order total operator: 1.9958508315755734
# processing psi0, given type: <class 'int'>
# ratio = -2.016
# [-0.3610981   0.27296385 -0.31610862  0.14112809 -0.31610862  0.27296385
#  -0.3610981 ]
# bond order total operator: 2.041469225633804
# processing psi0, given type: <class 'int'>
# ratio = -1.95
# [-0.37149187  0.27877518 -0.32335544  0.14323929 -0.32335544  0.27877518
#  -0.37149187]
# bond order total operator: 2.0904842740455503
# processing psi0, given type: <class 'int'>
# ratio = -1.884
# [-0.38275298  0.28489534 -0.33119396  0.1455918  -0.33119396  0.28489534
#  -0.38275298]
# bond order total operator: 2.1432763644238424
# processing psi0, given type: <class 'int'>
# ratio = -1.818
# [-0.39499618  0.29133361 -0.33969867  0.14821875 -0.33969867  0.29133361
#  -0.39499618]
# bond order total operator: 2.200275679581801
# processing psi0, given type: <class 'int'>
# ratio = -1.752
# [-0.40835548  0.29809294 -0.34895605  0.1511583  -0.34895605  0.29809294
#  -0.40835548]
# bond order total operator: 2.2619672271553393
# processing psi0, given type: <class 'int'>
# ratio = -1.686
# [-0.42298739  0.30516613 -0.35906678  0.1544541  -0.35906678  0.30516613
#  -0.42298739]
# bond order total operator: 2.3288947000003843
# processing psi0, given type: <class 'int'>
# ratio = -1.62
# [-0.43907468  0.31252994 -0.37014831  0.15815578 -0.37014831  0.31252994
#  -0.43907468]
# bond order total operator: 2.4016616455590274
# processing psi0, given type: <class 'int'>
# ratio = -1.5539999999999998
# [-0.45683002  0.32013641 -0.38233779  0.1623189  -0.38233779  0.32013641
#  -0.45683002]
# bond order total operator: 2.480927346258175
# processing psi0, given type: <class 'int'>
# ratio = -1.488
# [-0.47649909  0.3278999  -0.39579543  0.16700426 -0.39579543  0.3278999
#  -0.47649909]
# bond order total operator: 2.567393113666767
# processing psi0, given type: <class 'int'>
# ratio = -1.4220000000000002
# [-0.498362    0.33567807 -0.41070818  0.17227563 -0.41070818  0.33567807
#  -0.498362  ]
# bond order total operator: 2.6617721369224925
# processing psi0, given type: <class 'int'>
# ratio = -1.3559999999999999
# [-0.52273055  0.34324433 -0.42729387  0.17819496 -0.42729387  0.34324433
#  -0.52273055]
# bond order total operator: 2.7647324682466703
# processing psi0, given type: <class 'int'>
# ratio = -1.29
# [-0.54993779  0.35024893 -0.44580605  0.18481305 -0.44580605  0.35024893
#  -0.54993779]
# bond order total operator: 2.876798589431484
# processing psi0, given type: <class 'int'>
# ratio = -1.2239999999999998
# [-0.58031323  0.35616672 -0.4665408   0.1921529  -0.4665408   0.35616672
#  -0.58031323]
# bond order total operator: 2.99819439391524
# processing psi0, given type: <class 'int'>
# ratio = -1.158
# [-0.61413483  0.36023298 -0.48984916  0.20018175 -0.48984916  0.36023298
#  -0.61413483]
# bond order total operator: 3.1286156881596536
# processing psi0, given type: <class 'int'>
# ratio = -1.092
# [-0.651547    0.3613788  -0.51616489  0.20876701 -0.51616489  0.3613788
#  -0.651547  ]
# bond order total operator: 3.2669483901910925
# processing psi0, given type: <class 'int'>
# ratio = -1.0259999999999998
# [-0.69243931  0.35819826 -0.54606961  0.21761177 -0.54606961  0.35819826
#  -0.69243931]
# bond order total operator: 3.4110261353179343
# processing psi0, given type: <class 'int'>
# ratio = -0.96
# [-0.73630371  0.34901251 -0.58043646  0.22616632 -0.58043646  0.34901251
#  -0.73630371]
# bond order total operator: 3.557671667167232
# processing psi0, given type: <class 'int'>
# ratio = -0.8940000000000001
# [-0.78213938  0.33211779 -0.620706    0.23350176 -0.620706    0.33211779
#  -0.78213938]
# bond order total operator: 3.70342809313146
# processing psi0, given type: <class 'int'>
# ratio = -0.8279999999999998
# [-0.82853815  0.30623366 -0.66928396  0.23806302 -0.66928396  0.30623366
#  -0.82853815]
# bond order total operator: 3.8461745583868616
# processing psi0, given type: <class 'int'>
# ratio = -0.762
# [-0.87404562  0.27083851 -0.72970156  0.23697321 -0.72970156  0.27083851
#  -0.87404562]
# bond order total operator: 3.9861445872888064
# processing psi0, given type: <class 'int'>
# ratio = -0.6960000000000002
# [-0.91749207  0.22538792 -0.80509008  0.22406657 -0.80509008  0.22538792
#  -0.91749207]
# bond order total operator: 4.120006715297095
# processing psi0, given type: <class 'int'>
# ratio = -0.6299999999999999
# [-0.9570655   0.16612307 -0.89164309  0.18622042 -0.89164309  0.16612307
#  -0.9570655 ]
# bond order total operator: 4.215883724216848
# processing psi0, given type: <class 'int'>
# ratio = -0.5640000000000001
# [-0.98720417  0.08347246 -0.96724313  0.10441919 -0.96724313  0.08347246
#  -0.98720417]
# bond order total operator: 4.180258715683609
# processing psi0, given type: <class 'int'>
# ratio = -0.4979999999999998
# [-0.99924902 -0.02705503 -0.99883969 -0.02434198 -0.99883969 -0.02705503
#  -0.99924902]
# bond order total operator: 3.917725383379823
# processing psi0, given type: <class 'int'>
# ratio = -0.43199999999999994
# [-0.99209106 -0.1489698  -0.98190812 -0.1687308  -0.98190812 -0.1489698
#  -0.99209106]
# bond order total operator: 3.4813279625052473
# processing psi0, given type: <class 'int'>
# ratio = -0.3660000000000001
# [-0.97411802 -0.2602694  -0.94216595 -0.29536952 -0.94216595 -0.2602694
#  -0.97411802]
# bond order total operator: 3.016659621938542
# processing psi0, given type: <class 'int'>
# ratio = -0.2999999999999998
# [-0.9531166  -0.35215793 -0.90080676 -0.39414513 -0.90080676 -0.35215793
#  -0.9531166 ]
# bond order total operator: 2.6093857333493053
# processing psi0, given type: <class 'int'>
# ratio = -0.23399999999999999
# [-0.93269554 -0.42543295 -0.86559967 -0.46841145 -0.86559967 -0.42543295
#  -0.93269554]
# bond order total operator: 2.2773130584819197
# processing psi0, given type: <class 'int'>
# ratio = -0.1679999999999997
# [-0.91397512 -0.48348058 -0.83754622 -0.5240079  -0.83754622 -0.48348058
#  -0.91397512]
# bond order total operator: 2.0120736120326037
# processing psi0, given type: <class 'int'>
# ratio = -0.10199999999999987
# [-0.89711943 -0.52955489 -0.81562102 -0.56581926 -0.81562102 -0.52955489
#  -0.89711943]
# bond order total operator: 1.8005518742409186
# processing psi0, given type: <class 'int'>
# ratio = -0.03600000000000003
# [-0.88199695 -0.56625848 -0.79850813 -0.59744286 -0.79850813 -0.56625848
#  -0.88199695]
# bond order total operator: 1.631050336509076
# processing psi0, given type: <class 'int'>
# ratio = 0.03000000000000025
# [-0.86840846 -0.59560183 -0.78507065 -0.6214844  -0.78507065 -0.59560183
#  -0.86840846]
# bond order total operator: 1.4942701712638722
# processing psi0, given type: <class 'int'>
# ratio = 0.09600000000000009
# [-0.85615687 -0.61913949 -0.7744228  -0.63984955 -0.7744228  -0.61913949
#  -0.85615687]
# bond order total operator: 1.3830308128790003
# processing psi0, given type: <class 'int'>
# ratio = 0.16199999999999992
# [-0.84506529 -0.63808171 -0.76589848 -0.65394809 -0.76589848 -0.63808171
#  -0.84506529]
# bond order total operator: 1.2918160366066505
# processing psi0, given type: <class 'int'>
# ratio = 0.2280000000000002
# [-0.83497975 -0.65337553 -0.75900263 -0.6648311  -0.75900263 -0.65337553
#  -0.83497975]
# bond order total operator: 1.2163826105674136
# processing psi0, given type: <class 'int'>
# ratio = 0.29400000000000004
# [-0.8257676  -0.6657642  -0.75336798 -0.67328567 -0.75336798 -0.6657642
#  -0.8257676 ]
# bond order total operator: 1.153457089832624
# processing psi0, given type: <class 'int'>
# ratio = 0.3599999999999999
# [-0.81731506 -0.67583205 -0.74872121 -0.67990274 -0.74872121 -0.67583205
#  -0.81731506]
# bond order total operator: 1.1005056837351228
# processing psi0, given type: <class 'int'>
# ratio = 0.4259999999999997
# [-0.80952477 -0.68403918 -0.74485767 -0.68512678 -0.74485767 -0.68403918
#  -0.80952477]
# bond order total operator: 1.0555597464706317
# processing psi0, given type: <class 'int'>
# ratio = 0.49200000000000044
# [-0.80231361 -0.69074856 -0.74162291 -0.6892927  -0.74162291 -0.69074856
#  -0.80231361]
# bond order total operator: 1.017083215021195
# processing psi0, given type: <class 'int'>
# ratio = 0.5580000000000003
# [-0.7956106  -0.69624725 -0.73889926 -0.69265341 -0.73889926 -0.69624725
#  -0.7956106 ]
# bond order total operator: 0.98387181930523
# processing psi0, given type: <class 'int'>
# ratio = 0.6240000000000001
# [-0.78935519 -0.70076295 -0.73659616 -0.69540037 -0.73659616 -0.70076295
#  -0.78935519]
# bond order total operator: 0.9549764314937107
# processing psi0, given type: <class 'int'>
# ratio = 0.69
# [-0.78349565 -0.70447694 -0.73464312 -0.69767889 -0.73464312 -0.70447694
#  -0.78349565]
# bond order total operator: 0.9296447563760258
# processing psi0, given type: <class 'int'>
# ratio = 0.7559999999999998
# [-0.77798771 -0.70753415 -0.7329847  -0.69959958 -0.7329847  -0.70753415
#  -0.77798771]
# bond order total operator: 0.9072769359894501
# processing psi0, given type: <class 'int'>
# ratio = 0.8220000000000005
# [-0.77279343 -0.71005089 -0.73157676 -0.70124691 -0.73157676 -0.71005089
#  -0.77279343]
# bond order total operator: 0.8873916921278308
# processing psi0, given type: <class 'int'>
# ratio = 0.8880000000000003
# [-0.76788017 -0.71212098 -0.73038379 -0.70268552 -0.73038379 -0.71212098
#  -0.76788017]
# bond order total operator: 0.8696004412140526
# processing psi0, given type: <class 'int'>
# ratio = 0.9540000000000002
# [-0.76321977 -0.71382042 -0.72937689 -0.70396504 -0.72937689 -0.71382042
#  -0.76321977]
# bond order total operator: 0.8535874402638647
# processing psi0, given type: <class 'int'>
# ratio = 1.02
# [-0.75878786 -0.71521106 -0.72853227 -0.70512363 -0.72853227 -0.71521106
#  -0.75878786]
# bond order total operator: 0.8390944999133594
# processing psi0, given type: <class 'int'>
# ratio = 1.0859999999999999
# [-0.75456322 -0.71634347 -0.72783018 -0.70619072 -0.72783018 -0.71634347
#  -0.75456322]
# bond order total operator: 0.82590916265601
# processing psi0, given type: <class 'int'>
# ratio = 1.1520000000000006
# [-0.75052736 -0.71725917 -0.72725406 -0.70718898 -0.72725406 -0.71725917
#  -0.75052736]
# bond order total operator: 0.8138555175800503
# processing psi0, given type: <class 'int'>
# ratio = 1.2180000000000004
# [-0.74666404 -0.71799242 -0.72678986 -0.70813592 -0.72678986 -0.71799242
#  -0.74666404]
# bond order total operator: 0.8027870279872245
# processing psi0, given type: <class 'int'>
# ratio = 1.2840000000000003
# [-0.74295897 -0.71857157 -0.72642558 -0.70904505 -0.72642558 -0.71857157
#  -0.74295897]
# bond order total operator: 0.7925809018563781
# processing psi0, given type: <class 'int'>
# ratio = 1.35
# [-0.73939952 -0.71902021 -0.72615089 -0.70992675 -0.72615089 -0.71902021
#  -0.73939952]
# bond order total operator: 0.7831336500030478
# processing psi0, given type: <class 'int'>
# ratio = 1.416
# [-0.73597446 -0.719358   -0.72595681 -0.71078899 -0.72595681 -0.719358
#  -0.73597446]
# bond order total operator: 0.7743575627541963
# processing psi0, given type: <class 'int'>
# ratio = 1.4819999999999998
# [-0.73267378 -0.71960141 -0.72583552 -0.71163787 -0.72583552 -0.71960141
#  -0.73267378]
# bond order total operator: 0.7661779003708626
# processing psi0, given type: <class 'int'>
# ratio = 1.5480000000000005
# [-0.72948852 -0.71976429 -0.72578009 -0.71247798 -0.72578009 -0.71976429
#  -0.72948852]
# bond order total operator: 0.7585306408241689
# processing psi0, given type: <class 'int'>
# ratio = 1.6140000000000003
# [-0.7264106  -0.71985829 -0.72578442 -0.71331278 -0.72578442 -0.71985829
#  -0.7264106 ]
# bond order total operator: 0.7513606649610122
# processing psi0, given type: <class 'int'>
# ratio = 1.6800000000000002
# [-0.72343276 -0.71989326 -0.72584305 -0.71414482 -0.72584305 -0.71989326
#  -0.72343276]
# bond order total operator: 0.7446202866261273
# processing psi0, given type: <class 'int'>
# ratio = 1.746
# [-0.7205484  -0.71987752 -0.72595111 -0.71497593 -0.72595111 -0.71987752
#  -0.7205484 ]
# bond order total operator: 0.7382680561908752
# processing psi0, given type: <class 'int'>
# ratio = 1.8119999999999998
# [-0.71775154 -0.71981817 -0.72610421 -0.71580738 -0.72610421 -0.71981817
#  -0.71775154]
# bond order total operator: 0.7322677818444532
# processing psi0, given type: <class 'int'>
# ratio = 1.8780000000000006
# [-0.71503669 -0.7197212  -0.72629837 -0.71664001 -0.72629837 -0.7197212
#  -0.71503669]
# bond order total operator: 0.7265877251690926
# processing psi0, given type: <class 'int'>
# ratio = 1.9440000000000004
# [-0.71239887 -0.71959175 -0.72652999 -0.7174743  -0.72652999 -0.71959175
#  -0.71239887]
# bond order total operator: 0.7211999368666183
# processing psi0, given type: <class 'int'>
# ratio = 2.0100000000000002
# [-0.70983348 -0.71943418 -0.72679579 -0.71831047 -0.72679579 -0.71943418
#  -0.70983348]
# bond order total operator: 0.7160797057155126
# processing psi0, given type: <class 'int'>
# ratio = 2.076
# [-0.7073363  -0.71925222 -0.72709274 -0.71914854 -0.72709274 -0.71925222
#  -0.7073363 ]
# bond order total operator: 0.7112050994274732
# processing psi0, given type: <class 'int'>
# ratio = 2.142
# [-0.70490343 -0.71904905 -0.72741809 -0.71998836 -0.72741809 -0.71904905
#  -0.70490343]
# bond order total operator: 0.7065565804246058
# processing psi0, given type: <class 'int'>
# ratio = 2.2079999999999997
# [-0.70253126 -0.7188274  -0.72776931 -0.72082965 -0.72776931 -0.7188274
#  -0.70253126]
# bond order total operator: 0.702116682962121
# processing psi0, given type: <class 'int'>
# ratio = 2.2740000000000005
# [-0.70021646 -0.71858959 -0.72814402 -0.72167203 -0.72814402 -0.71858959
#  -0.70021646]
# bond order total operator: 0.6978697406950343
# processing psi0, given type: <class 'int'>
# ratio = 2.3400000000000003
# [-0.69795591 -0.71833761 -0.72854007 -0.72251508 -0.72854007 -0.71833761
#  -0.69795591]
# bond order total operator: 0.6938016558968723
# processing psi0, given type: <class 'int'>
# ratio = 2.406
# [-0.69574673 -0.71807316 -0.72895543 -0.72335829 -0.72895543 -0.71807316
#  -0.69574673]
# bond order total operator: 0.6898997032097668
# processing psi0, given type: <class 'int'>
# ratio = 2.472
# [-0.69358621 -0.71779768 -0.72938822 -0.72420114 -0.72938822 -0.71779768
#  -0.69358621]
# bond order total operator: 0.6861523621353558
# processing psi0, given type: <class 'int'>
# ratio = 2.538
# [-0.69147184 -0.7175124  -0.72983669 -0.72504309 -0.72983669 -0.7175124
#  -0.69147184]
# bond order total operator: 0.6825491735385257
# processing psi0, given type: <class 'int'>
# ratio = 2.6040000000000005
# [-0.68940125 -0.71721836 -0.7302992  -0.72588356 -0.7302992  -0.71721836
#  -0.68940125]
# bond order total operator: 0.6790806162886233
# processing psi0, given type: <class 'int'>
# ratio = 2.6700000000000004
# [-0.68737223 -0.71691647 -0.73077422 -0.72672198 -0.73077422 -0.71691647
#  -0.68737223]
# bond order total operator: 0.6757380008493897
# processing psi0, given type: <class 'int'>
# ratio = 2.736
# [-0.68538271 -0.71660745 -0.73126032 -0.72755778 -0.73126032 -0.71660745
#  -0.68538271]
# bond order total operator: 0.6725133771841908
# processing psi0, given type: <class 'int'>
# ratio = 2.802
# [-0.68343073 -0.71629195 -0.73175614 -0.7283904  -0.73175614 -0.71629195
#  -0.68343073]
# bond order total operator: 0.6693994547937233
# processing psi0, given type: <class 'int'>
# ratio = 2.868
# [-0.68151446 -0.71597048 -0.73226043 -0.72921928 -0.73226043 -0.71597048
#  -0.68151446]
# bond order total operator: 0.6663895330705751
# processing psi0, given type: <class 'int'>
# ratio = 2.9340000000000006
# [-0.67963216 -0.71564349 -0.73277199 -0.73004387 -0.73277199 -0.71564349
#  -0.67963216]
# bond order total operator: 0.6634774404551815
# processing psi0, given type: <class 'int'>
# ratio = 3.0
# [-0.67778219 -0.71531132 -0.73328969 -0.73086363 -0.73328969 -0.71531132
#  -0.67778219]
# bond order total operator: 0.6606574811240803

# %%
plt.plot(J_parallel_sweep/np.abs(J), bond_order_parameters)

# %% [markdown]
# with strong interactions ![image.png](attachment:image.png)

# %%
keys = ('simulation', 'no_dephasing')


data_filename = 'bond_order_parameter_simulation_data.h5'


data_dictionary = {
    'J_parallel_sweep': J_parallel_sweep,
    'bond_order_parameters': bond_order_parameters,
    'J': J,
    'U': U,
}

update_data_file(data_filename, data_dictionary, keys=keys, save_backup=True)

# %% [markdown]
# # 2. With Dephasing

# %% [markdown]
# ### 2.1 Import T2s from config file

# %%
config_filename = 'bond_order_config.json'

with open(config_filename, "r") as f:
    config = json.load(f)


current_correlations_filename = '../current_correlations/current_correlations_config.json'

with open(current_correlations_filename, "r") as f:
    current_correlations_config = json.load(f)

print("Loaded config keys:", list(config.keys()))


coupling_points = [
    "coupling_point_1",
    "coupling_point_2_retake",
    "coupling_point_3",
    "coupling_point_4",
    "coupling_point_5_retake",
    "coupling_point_6_retake",
]

all_T2s = np.zeros((len(coupling_points), num_qubits))


for coupling_point in coupling_points:

    coupling_point_base = coupling_point.rsplit('_', 1)[0]

    coupling_point_index = int(coupling_point.split('_')[2]) - 1

    if coupling_point in current_correlations_config and 'T2s' in current_correlations_config[coupling_point]:
        T2_dict = current_correlations_config[coupling_point]['T2s']
    elif coupling_point_base in current_correlations_config and 'T2s' in current_correlations_config[coupling_point_base]:
        T2_dict = current_correlations_config[coupling_point_base]['T2s']
    else:
        raise ValueError(f"No T2s found for coupling point {coupling_point} or its base {coupling_point_base} in current correlations config")

    for T2_qubit in T2_dict:
        qubit_index = int(T2_qubit.split('_')[-1]) - 1
        all_T2s[coupling_point_index, qubit_index] = T2_dict[T2_qubit]

print(all_T2s)

min_T2s = np.min(all_T2s, axis=0)
max_T2s = np.max(all_T2s, axis=0)
average_T2s = np.mean(all_T2s, axis=0)

print(min_T2s)
print(max_T2s)
print(average_T2s)
# Out:
# Loaded config keys: ['coupling_point_1', 'coupling_point_2', 'coupling_point_4', 'coupling_point_3', 'coupling_point_5', 'coupling_point_6', 'coupling_point_6_retake', 'coupling_point_5_retake', 'coupling_point_2_retake']
# [[1.044 0.959 0.526 1.001 0.652 0.587 1.479 0.835]
#  [2.085 0.581 1.976 0.366 2.119 2.005 1.727 1.792]
#  [1.467 0.535 1.543 0.422 2.396 2.036 1.371 1.621]
#  [2.186 0.74  2.597 1.485 2.077 2.522 2.33  1.934]
#  [3.309 1.068 1.064 0.271 5.117 3.738 5.685 3.499]
#  [2.962 0.222 3.395 0.271 3.526 2.941 5.453 2.504]]
# [1.044 0.222 0.526 0.271 0.652 0.587 1.371 0.835]
# [3.309 1.068 3.395 1.485 5.117 3.738 5.685 3.499]
# [2.1755     0.68416667 1.85016667 0.636      2.64783333 2.30483333
#  3.0075     2.03083333]

# %% [markdown]
# ### 2.2 Sweep $J_{||}/J$

# %%
### initialize parameters

dephasing = 0.5
# dephasing = 'real_min'


J = -5.5 * 2 * np.pi # 2pi MHz
U = -180 * 2 * np.pi # 2pi MHz

T1 = None
T2 = None

psi0 = -1
times = np.linspace(0, 0.15, 11)


ratios = np.linspace(-3, 3, 11)
ratios = np.linspace(-3.5, 3.5, 11)
# ratios = np.array([1])

J_parallel_sweep = np.abs(J) * ratios

# %%
num_levels = 5
num_qubits = 8
num_particles = 4

basis = list(product(range(num_levels), repeat=num_qubits))
basis_4Q = [state for state in basis if sum(state) == num_particles]




pairs = []
for i in range(1, 8):
    pairs.append((i, i+1))

# %%
ramp_time_ns = 290 # ns

Q8_couplings_3m = {}

for i in range(num_qubits - 1):
    Q8_couplings_3m[(i+1,i+2)] = J/1e3/2/np.pi


U_GHz_list = [-U/1e3/2/np.pi] * num_qubits


init_ff = np.array([0, -0.1, -0.1, 0, 0, -0.1, -0.1, 0]) * 1.5
expt_ff = [0,0,0,0,0,0,0,0]


if isinstance(dephasing, str):
    if dephasing == 'real_min':
        T2_list = np.array(min_T2s)*1e3 # ns
    elif dephasing == 'real_max':
        T2_list = np.array(max_T2s)*1e3 # ns

else:
    T2_list = [dephasing*1e3]*num_qubits # ns

T2_list = np.array(T2_list, dtype=np.float64)

print(f'T2 list for dephasing {dephasing}: {T2_list} ')
# Out:
# T2 list for dephasing 0.5: [500. 500. 500. 500. 500. 500. 500. 500.]

# %%
# ramp_shape = simple_ramp
# tlist = np.linspace(0, ramp_time_ns, 5)




# Q8_3m = M_qubit_sys_reduced(w=[0]*num_qubits, U=U_GHz_list,
#             couplings=Q8_couplings_3m,
#                         time_deps = {1: ramp_shape(init_ff[0],expt_ff[0], ramp_time_ns),
#                                     2: ramp_shape(init_ff[1],expt_ff[1], ramp_time_ns),
#                                     3: ramp_shape(init_ff[2],expt_ff[2], ramp_time_ns),
#                                     4: ramp_shape(init_ff[3],expt_ff[3], ramp_time_ns),
#                                     5: ramp_shape(init_ff[4],expt_ff[4], ramp_time_ns),
#                                     6: ramp_shape(init_ff[5],expt_ff[5], ramp_time_ns),
#                                     7: ramp_shape(init_ff[6],expt_ff[6], ramp_time_ns),
#                                     8: ramp_shape(init_ff[7],expt_ff[7], ramp_time_ns)},
#                         T2s=T2_list,
#                 RWA=True, N=5, reduce_Hamil_to_n=4)

# prep_state = Q8_3m.reduce_ket(Q8_3m.fock([1,0,0,1,1,0,0,1]))

# res = Q8_3m.mesolve(prep_state, tlist, options={'store_states':True}, plot=False)

# final_state = res.states[-1]

# true_eigenstate = Q8_3m.eigstates(4)[-1]
# overlap = np.abs(final_state.overlap(true_eigenstate))

# psi0_state = final_state

# %%
bond_order_parameters = []

for i in range(len(J_parallel_sweep)):

    J_parallel = J_parallel_sweep[i]

    for i in range(num_qubits - 2):
        Q8_couplings_3m[(i+1,i+3)] = J_parallel/1e3/2/np.pi


    ramp_shape = simple_ramp
    tlist = np.linspace(0, ramp_time_ns, 5)




    Q8_3m = M_qubit_sys_reduced(w=[0]*num_qubits, U=U_GHz_list,
                couplings=Q8_couplings_3m,
                            time_deps = {1: ramp_shape(init_ff[0],expt_ff[0], ramp_time_ns),
                                        2: ramp_shape(init_ff[1],expt_ff[1], ramp_time_ns),
                                        3: ramp_shape(init_ff[2],expt_ff[2], ramp_time_ns),
                                        4: ramp_shape(init_ff[3],expt_ff[3], ramp_time_ns),
                                        5: ramp_shape(init_ff[4],expt_ff[4], ramp_time_ns),
                                        6: ramp_shape(init_ff[5],expt_ff[5], ramp_time_ns),
                                        7: ramp_shape(init_ff[6],expt_ff[6], ramp_time_ns),
                                        8: ramp_shape(init_ff[7],expt_ff[7], ramp_time_ns)},
                            T2s=T2_list,
                    RWA=True, N=5, reduce_Hamil_to_n=4)

    prep_state = Q8_3m.reduce_ket(Q8_3m.fock([1,0,0,1,1,0,0,1]))

    res = Q8_3m.mesolve(prep_state, tlist, options={'store_states':True}, plot=False)

    final_state = res.states[-1]

    true_eigenstate = Q8_3m.eigstates(4)[-1]
    overlap = np.abs(final_state.overlap(true_eigenstate))

    psi0_state = final_state

    # create fock state out of psi0

    basis_4Q_fock = [FockBasisState(state) for state in basis_4Q]

    # basis_fock = [FockBasisState(state) for state in basis]

    psi0_fock_basis = []
    psi0_fock_state = []

    trace_sum = 0

    for i in range(len(basis_4Q)):
        for j in range(len(basis_4Q)):
            coeff = psi0_state.full()[i,j]
            if abs(coeff) > 1e-10:
                psi0_fock_basis.append(FockBasisOuter(basis_4Q[i], basis_4Q[j]))
                psi0_fock_state.append(coeff)

        trace_sum += psi0_state.full()[i,i]

    psi0_fock = DensityMatrix(np.array(psi0_fock_state), psi0_fock_basis)


    # remove pairs that share a vertex, and redefine signs (1,2),(4,5) is positive in pi flux

    bond_order_value_from_operator = {}

    for pair in pairs:
        new_state = psi0_fock.apply_raising_operator_left(pair[0]-1, num_levels).apply_lowering_operator_left(pair[1]-1)
        value = new_state.trace()
        bond_order_value_from_operator[pair] = 2*value.real

    bond_order_value_operators = np.array([bond_order_value_from_operator[pair] for pair in pairs])

    bond_order_total_operator = 0
    for pair in pairs:
        bond_order_total_operator += bond_order_value_from_operator[pair] * (-1)**(pair[0])  # alternating sign    

    bond_order_parameters.append(bond_order_total_operator)
# Out:
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 93.71909379959106 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.0736379623413086 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 82.00797009468079 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06673145294189453 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 96.80704116821289 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.0653839111328125 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 94.11487984657288 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.07400751113891602 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 118.44563269615173 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06432366371154785 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 109.19643974304199 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06791210174560547 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 90.89159345626831 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06881165504455566 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 72.81055045127869 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06650710105895996 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 59.94916653633118 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06322383880615234 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 58.62401366233826 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06467866897583008 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 105.02625584602356 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06430554389953613 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 97.88121104240417 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06362509727478027 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 76.94139742851257 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06363844871520996 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 103.13901495933533 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06715011596679688 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 89.9071843624115 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06701827049255371 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 76.97430515289307 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06813788414001465 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 90.28871488571167 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06659197807312012 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 89.20050764083862 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06487751007080078 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 97.20321750640869 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06675004959106445 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 100.76225805282593 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06497859954833984 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 98.45249843597412 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06525039672851562 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 106.25150465965271 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06596112251281738 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 110.21399974822998 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06639623641967773 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 90.43793725967407 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06677412986755371 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 61.528533697128296 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06528687477111816 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 101.50970482826233 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06483888626098633 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 60.018189430236816 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06446027755737305 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 85.78536081314087 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06512832641601562 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 112.41920757293701 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06424117088317871 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 107.83538341522217 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06697893142700195 seconds to diagonalize.
# Reduced 390625^2-dimensional subspace to a 330^2-dimensional one.
# [None, None, None, None, None, None, None, None, None]
# [ nan 500. 500. 500. 500. 500. 500. 500. 500.]
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002
# 5 time steps for 8 qubits and N=5 took 82.59704566001892 seconds to simulate.
# Hamiltonian of shape (330, 330) took 0.06401419639587402 seconds to diagonalize.

# %%
plt.plot(J_parallel_sweep/np.abs(J), bond_order_parameters, marker='o')

plt.xlabel('J_parallel / J')
plt.ylabel('Bond Order Parameter')
plt.title(f'Bond Order Parameter vs J_parallel/J for dephasing {dephasing} T2')
plt.grid()
plt.show()

# %%
keys = ('simulation', dephasing)


data_filename = 'bond_order_parameter_simulation_data.h5'


data_dictionary = {
    'J_parallel_sweep': J_parallel_sweep,
    'bond_order_parameters': bond_order_parameters,
    'J': J,
    'U': U,
}

update_data_file(data_filename, data_dictionary, keys=keys, save_backup=True)

# %% [markdown]
# # 3. Plots

# %%
data_filename = 'bond_order_parameter_simulation_data.h5'
loaded_data = load_nested_dict_from_hdf5(data_filename)
print_tree(loaded_data['simulation'])
# Out:
# 0.5
# - J_parallel_sweep
# - bond_order_parameters
# - J
# - U
# no_dephasing
# - J_parallel_sweep
# - bond_order_parameters
# - J
# - U
# real_max
# - J_parallel_sweep
# - bond_order_parameters
# - J
# - U
# real_min
# - J_parallel_sweep
# - bond_order_parameters
# - J
# - U

# %%
real_min_chiral_order_parameters = loaded_data['simulation']['real_min']['bond_order_parameters']
real_min_J_parallel_sweep = loaded_data['simulation']['real_min']['J_parallel_sweep']
real_min_J = loaded_data['simulation']['real_min']['J']

real_min_chiral_order_parameters = loaded_data['simulation']['real_max']['bond_order_parameters']
real_min_J_parallel_sweep = loaded_data['simulation']['real_max']['J_parallel_sweep']
real_min_J = loaded_data['simulation']['real_max']['J']

# %%
for dephasing in loaded_data['simulation']:
    dephasing_bond_order_parameters = loaded_data['simulation'][dephasing]['bond_order_parameters']
    dephasing_J_parallel_sweep = loaded_data['simulation'][dephasing]['J_parallel_sweep']
    dephasing_J = np.abs(loaded_data['simulation'][dephasing]['J'])
    
    plt.plot(dephasing_J_parallel_sweep/dephasing_J, dephasing_bond_order_parameters, marker='o', label=dephasing)

plt.xlabel('J_parallel / J')
plt.ylabel('Bond Order Parameter')
plt.title('Bond Order Parameter vs J_parallel/J for Realistic T2 Ranges')
plt.legend()
plt.grid()
plt.show()

# %%
no_dephasing_bond_order_parameters = loaded_data['simulation']['no_dephasing']['bond_order_parameters']
no_dephasing_J_parallel_sweep = loaded_data['simulation']['no_dephasing']['J_parallel_sweep']
no_dephasing_J = loaded_data['simulation']['no_dephasing']['J']

try:
    real_min_bond_order_parameters = loaded_data['simulation']['real_min']['bond_order_parameters']
    real_min_J_parallel_sweep = loaded_data['simulation']['real_min']['J_parallel_sweep']
    real_min_J = loaded_data['simulation']['real_min']['J']
except:
    pass

real_max_bond_order_parameters = loaded_data['simulation']['real_max']['bond_order_parameters']
real_max_J_parallel_sweep = loaded_data['simulation']['real_max']['J_parallel_sweep']
real_max_J = loaded_data['simulation']['real_max']['J']


plt.plot(no_dephasing_J_parallel_sweep/np.abs(no_dephasing_J), no_dephasing_bond_order_parameters, marker='o', label='no dephasing')
plt.plot(real_min_J_parallel_sweep/np.abs(real_min_J), real_min_bond_order_parameters, marker='o', label='realistic min T2')
plt.plot(real_max_J_parallel_sweep/np.abs(real_max_J), real_max_bond_order_parameters, marker='s', label='realistic max T2')

plt.xlabel('J_parallel / J')
plt.ylabel('Bond Order Parameter')
plt.title('Bond Order Parameter vs J_parallel/J for Realistic T2 Ranges')
plt.legend()
plt.grid()
plt.show()

# %%
coupling_points = [
'coupling_point_1',
'coupling_point_2_retake',
'coupling_point_3',
'coupling_point_4',
'coupling_point_5_retake',
'coupling_point_6_retake',
]

# %%
print_tree(bond_order_data['simulation']['highest']['no_dephasing'],max_level=1)
# Out:
# coupling_point_1
# coupling_point_2
# coupling_point_2_retake
# coupling_point_3
# coupling_point_4
# coupling_point_5
# coupling_point_5_retake
# coupling_point_6
# coupling_point_6_retake

# %%
### let's import the current correlations data
bond_order_data_filename = 'bond_order_data.h5'

bond_order_data = load_nested_dict_from_hdf5(bond_order_data_filename)

bond_order_parameters_data = np.array([bond_order_data['data'][coupling_point]['highest_postselection']['bond_order_total_corrected'] for coupling_point in coupling_points])


bond_order_parameters_error = []
for coupling_point in coupling_points:
    coupling_point_base = coupling_point.split('_retake')[0]  # remove _retake if it exists
    print(coupling_point)
    if 'bond_order_total_readout_std_error' in bond_order_data['data'][coupling_point]['highest_postselection']:
        print(f'found readout error std error for coupling point {coupling_point}')
        bond_order_parameters_error.append(bond_order_data['data'][coupling_point]['highest_postselection']['bond_order_total_readout_std_error'])
    elif 'bond_order_total_readout_std_error' in bond_order_data['data'][coupling_point_base]['highest_postselection']:
        print(f'found readout error std error for base coupling point {coupling_point_base}')
        bond_order_parameters_error.append(bond_order_data['data'][coupling_point_base]['highest_postselection']['bond_order_total_readout_std_error'])
    else:
        raise KeyError(f"Readout error std error not found for coupling point {coupling_point} or base coupling point {coupling_point_base}")
bond_order_parameters_error = np.array(bond_order_parameters_error)

print(bond_order_parameters_data)

bond_order_parameters_sim_BS_no_dephasing = np.array([bond_order_data['simulation']['highest']['no_dephasing'][coupling_point]['bond_order_total_BS'] for coupling_point in coupling_points])
bond_order_parameters_sim_BS_real = np.array([bond_order_data['simulation']['highest']['real'][coupling_point]['bond_order_total_BS'] for coupling_point in coupling_points])


average_rung_couplings = np.array([config[coupling_point]['coupling']['average_rung_coupling'] for coupling_point in coupling_points])
average_leg_couplings = np.array([config[coupling_point]['coupling']['average_leg_coupling'] for coupling_point in coupling_points])

for i in range(len(coupling_points)):
    print(f"Coupling point: {coupling_points[i]}, average rung coupling: {average_rung_couplings[i]}, average leg coupling: {average_leg_couplings[i]}")

data_ratios = -average_leg_couplings/average_rung_couplings

sorted_indices = np.argsort(data_ratios)

plt.plot(no_dephasing_J_parallel_sweep/np.abs(no_dephasing_J), no_dephasing_bond_order_parameters, color='black', linestyle='--', label='no dephasing')

plt.plot(data_ratios[sorted_indices], bond_order_parameters_sim_BS_no_dephasing[sorted_indices], color='green', linestyle=':', label='BS no dephasing')
plt.plot(data_ratios[sorted_indices], bond_order_parameters_sim_BS_real[sorted_indices], color='teal', linestyle=':', label='BS real')

# fill between real min and real max
plt.fill_between(real_min_J_parallel_sweep/np.abs(real_min_J), real_min_bond_order_parameters, real_max_bond_order_parameters, alpha=0.3, label='dephasing range')
plt.plot(real_min_J_parallel_sweep/np.abs(real_min_J), real_min_bond_order_parameters, color='blue', label='realistic min T2')
plt.plot(real_max_J_parallel_sweep/np.abs(real_max_J), real_max_bond_order_parameters, color='darkblue', label='realistic max T2')


plt.plot(data_ratios[sorted_indices], bond_order_parameters_data[sorted_indices], color='red', linestyle='', marker='o', label='experimental correlations')

plt.xlabel('J_parallel / J')
plt.ylabel('Bond Order Parameter')
plt.title('Bond Order Parameter vs J_parallel/J')
plt.legend()
plt.grid()
plt.show()
# Out:
# coupling_point_1
# found readout error std error for coupling point coupling_point_1
# coupling_point_2_retake
# found readout error std error for base coupling point coupling_point_2
# coupling_point_3
# found readout error std error for coupling point coupling_point_3
# coupling_point_4
# found readout error std error for coupling point coupling_point_4
# coupling_point_5_retake
# found readout error std error for coupling point coupling_point_5_retake
# coupling_point_6_retake
# found readout error std error for coupling point coupling_point_6_retake
# [1.42036972 0.67589371 0.2689402  0.56735498 0.48581846 0.08710544]
# Coupling point: coupling_point_1, average rung coupling: -5.748571428571429, average leg coupling: -6.996666666666667
# Coupling point: coupling_point_2_retake, average rung coupling: -6.048571428571428, average leg coupling: -12.214999999999998
# Coupling point: coupling_point_3, average rung coupling: -4.888571428571429, average leg coupling: -17.41333333333333
# Coupling point: coupling_point_4, average rung coupling: -6.4157142857142855, average leg coupling: 6.260000000000001
# Coupling point: coupling_point_5_retake, average rung coupling: -7.9871428571428575, average leg coupling: 16.31
# Coupling point: coupling_point_6_retake, average rung coupling: -8.615714285714287, average leg coupling: 24.583333333333332

# %%
sim_copmarison_all_points_filepath = 'plots/simulation_comparison_all_points.csv'

with open(sim_copmarison_all_points_filepath, 'w') as f:
    writer = csv.writer(f)

    writer.writerow(data_ratios[sorted_indices])
    writer.writerow(bond_order_parameters_data[sorted_indices])
    writer.writerow(bond_order_parameters_error[sorted_indices])
    writer.writerow(bond_order_parameters_sim_BS_no_dephasing[sorted_indices])
    writer.writerow(bond_order_parameters_sim_BS_real[sorted_indices])
    writer.writerow(no_dephasing_J_parallel_sweep/np.abs(no_dephasing_J))
    # writer.writerow(no_dephasing_bond_order_parameters/np.abs(no_dephasing_J/(2*np.pi)))
    writer.writerow(no_dephasing_bond_order_parameters)

    
    # order is
    # data ratios
    # data correlations
    # BS sim no dephasing
    # BS sim real T2

    # simulation ratios
    # simulation exact operator
