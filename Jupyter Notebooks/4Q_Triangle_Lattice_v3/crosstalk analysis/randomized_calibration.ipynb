# %%
import csv
import datetime
import random
import os

from itertools import product

import matplotlib.pyplot as plt
import numpy as np

import pulp
from scipy.optimize import minimize
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       3 import random
#       4 import os
# ----> 6 from crosstalk_flux_to_voltage_optimization import brute_force
#       8 from itertools import product
#      10 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'crosstalk_flux_to_voltage_optimization'

# %% [markdown]
# Assume we already exported random voltaegs and measured qubit frequency. Import the data and extract qubit frequency and flux values here
